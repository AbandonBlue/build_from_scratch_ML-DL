# %% [markdown]
# ## 決策樹實踐
# - 說明: 決策樹是隨機森林以及梯度提升樹的基礎，也是知名演算法LightGBM、XGBoost的基礎(因為本質就是梯度提升樹)，其模型透過如同人類決策般不斷根據特徵以及閾值進行切分，最終將原始資料分類或者回歸(平均)。
# - 演算法步驟:
#     1. 選擇一個特徵
#     2. 決定閾值
#     3. 計算Gini(/Entropy)[分類問題]、MSE(/MAE)[回歸問題]
#     4. 如果父節點的分數 < 子節點根據比例加權則代表可切分，並且記錄feature+threshold+y_hat
#         如果 > 則回到步驟1.
#     5. 當節點的樣本數、或者樹深度達到限制條件則停止，若不限制增長則會長到所有都是葉節點。
# - 優化方向
#     - 選擇最佳拆分特徵以及閾值 ---> 貪婪算法。
#
# ---
# 都以簡化實現，僅把主要邏輯實現為主，比如如何挑選特徵、如何找閾值。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.datasets import fetch_california_housing

# %matplotlib inline

# %%
## 測試資料

data = fetch_california_housing(as_frame=True)
X = data['data']
y = data['target']

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
## 拆分邏輯計算

# 1. 選擇一個特徵
feature_name = "HouseAge"
feature_name = np.random.choice(X.columns)
print(f"當前選擇特徵: {feature_name}")

# 2. 決定threshold
# 2.1 上下限從均勻選擇(可更新成其他選擇方式)

_max = X[feature_name].max()
_min = X[feature_name].min()
threshold = np.random.uniform(low=_min, high=_max, size=1)[0]
print(_min, _max, threshold)

# 3. 計算MSE
score_function = mean_absolute_error
current_sample_idx = X[feature_name].index
current_y_hat = y[current_sample_idx].mean()
current_y_hat = [current_y_hat] * len(current_sample_idx)

current_mse = score_function(y, current_y_hat)
print(f'當前節點(父)MSE: {current_mse}')

# 根據threshold 取得左節點、右節點
left_node = X[X[feature_name] < threshold]
right_node=  X[X[feature_name] >= threshold]

left_num_samples = len(left_node)
right_num_samples = len(right_node)


left_y = y[left_node.index]
right_y = y[right_node.index]

total_samples = len(left_y) + len(right_y)

left_y_hat = [left_y.mean()] * left_num_samples
right_y_hat = [right_y.mean()] *right_num_samples
left_mse = score_function(left_y, left_y_hat)
right_mse = score_function(right_y, right_y_hat)
print(f'左節點MSE: {left_mse}')
print(f'右節點MSE: {right_mse}')

# 計算切分分數
left_weight = left_num_samples / total_samples
right_weight = right_num_samples / total_samples
sub_sample_mse = left_mse * left_weight + right_mse * right_weight
print(f'左右加權MSE: {sub_sample_mse}')

# 判斷是否當前切分有比較好
is_more_pure = (current_mse > sub_sample_mse)
print(f"當前切分是否更pure: {is_more_pure}")
# Out:
# 當前選擇特徵: Latitude
# 32.54 41.95 36.454363166585765
# 當前節點(父)MSE: 0.9117043994367803
# 左節點MSE: 0.8802840637029075
# 右節點MSE: 0.9546865582524363
# 左右加權MSE: 0.910874159087951
# 當前切分是否更pure: True

# %%
## 當訓練完時，有一個規則去判斷
class RuleNode():
    def __init__(self, feature_name, threshold, num_samples, mse, value):
        self.feature_name = feature_name
        self.threshold = threshold
        self.num_samples = num_samples
        self.mse = mse
        self.value = value
        self.left = None
        self.right = None
        self.has_left = False
        self.has_right = False
    
    def get_prediction(self):
        return self.value
    
    def __repr__(self):
        return f"當前Node:\n-------\nfeature_name: {self.feature_name}\nthreshold: {self.threshold}\nnum_samples: {self.num_samples}\nmse: {self.mse}\nvalue: {self.value}\nhas_left: {self.has_left}\nhas_right: {self.has_right}\n-------"
        
current_node = RuleNode(feature_name, threshold, total_samples, current_mse, np.mean(current_y_hat))
current_node
# current_node.value
# Out:
# 當前Node:
# -------
# feature_name: Latitude
# threshold: 34.53896866454806
# num_samples: 20640
# mse: 0.9117043994367803
# value: 2.068558169089184
# has_left: False
# has_right: False
# -------

# %%
## 實踐一個回歸的，分類比較常有人做

class DecisionTreeRegressorSimple():
    def __init__(self, max_depth=None, criterion='MSE', min_samples_split=2, random_state=222):
        np.random.seed(random_state)
        self.max_depth = max_depth
        self.criterion = criterion
        if self.criterion == 'MSE':
            self.score_function = mean_squared_error
        else:
            self.score_function = mean_absolute_error
        self.min_samples_split = min_samples_split
        self.records = {}
        self.count = 0
        self.max_retry = 10
    
    def _get_random_feature(self, X):
        features = X.columns
        return np.random.choice(features)
    
    def _get_best_split_feature(self, X):
        ## TODO: 需要仔細看一下
#         best_feature = None
#         current_best_score = None
#         for feature in X.columns:
#             if best_feature is None:
#                 best_feature = feature
#             threshold = self._get_feature_threshold(X, feature)
#             # 父節點計算
#             current_sample_idx = X[feature].index
#             current_y_hat = y[current_sample_idx].mean()
#             total_samples = len(X)
#             current_mse = self.score_function(y, [current_y_hat] * total_samples)
            
#             # 切出左節點、右節點
#             left_X = X[X[feature] < threshold]
#             right_X =  X[X[feature] >= threshold]
#             left_num_samples = len(left_X)
#             right_num_samples = len(right_X)
#             left_y = y[left_X.index]
#             right_y = y[right_X.index]
#             left_y_hat = [left_y.mean()] * left_num_samples
#             right_y_hat = [right_y.mean()] * right_num_samples
#             left_score = self.score_function(left_y, left_y_hat)
#             right_score = self.score_function(right_y, right_y_hat)
#             left_weight = left_num_samples / total_samples
#             right_weight = right_num_samples / total_samples
#             sub_sample_mse = left_score * left_weight + right_score * right_weight
#             if current_best_score is None:
                
            
        
        return
    
    def _get_feature_threshold(self, X, feature):
        _max = X[feature].max()
        _min = X[feature].min()
        threshold = np.random.uniform(low=_min, high=_max, size=1)[0]
        return threshold
    
    def _record_rules(self):
        """
        當每次切分成功後，需要紀錄切分的`特徵`、`score`、`samples`、`value(y_hat)`
        """
        pass
    
    def _split_data(self, X, y, depth=0, retry_count=0):
        ## TODO: 沒有設計好，要思考一下！
        if len(X) == 0:
            return None
        if depth == self.max_depth:
            print(f'深度太深，請檢查')
            return None
        
        # 選擇特徵、閾值
        feature = self._get_random_feature(X)
        threshold = self._get_feature_threshold(X, feature)
        
        # 父節點計算
        current_sample_idx = X[feature].index
        current_y_hat = y[current_sample_idx].mean()
        total_samples = len(X)
        current_mse = self.score_function(y, [current_y_hat] * total_samples)
        
        # 父節點建立
        current_node = RuleNode(feature, threshold, total_samples, current_mse, current_y_hat)
        if depth == 0:
            self.root = current_node
        
        # 切出左節點、右節點
        left_X = X[X[feature] < threshold]
        right_X =  X[X[feature] >= threshold]
        left_num_samples = len(left_X)
        right_num_samples = len(right_X)
        left_y = y[left_X.index]
        right_y = y[right_X.index]
        
        if (left_num_samples == 0) or (right_num_samples == 0):
            #print(f'終結節點的樣本數: {total_samples}')
            #print(f'確認終端節點: 左邊: {left_num_samples}, 右邊: {right_num_samples}')
            #print(f'此時threshold: {threshold}, max: {X[feature].max()}, min: {X[feature].min()}')
            
            # 因為少了一邊都不需要切了
            current_node.left = None
            current_node.right = None
            return current_node

        # 計算左右節點切分分數
        left_y_hat = [left_y.mean()] * left_num_samples
        right_y_hat = [right_y.mean()] * right_num_samples
        left_score = self.score_function(left_y, left_y_hat)
        right_score = self.score_function(right_y, right_y_hat)
        left_weight = left_num_samples / total_samples
        right_weight = right_num_samples / total_samples
        sub_sample_mse = left_score * left_weight + right_score * right_weight
        #print(current_mse, sub_sample_mse, left_weight, right_weight)

        # 判斷是否當前切分有比較好
        is_more_pure = (current_mse > sub_sample_mse)
        if is_more_pure:
            #print(f'Pure時，切分特徵: {feature}, threhold: {threshold}, 左節點: {left_num_samples}, 右節點: {right_num_samples}')
            #print(f"is_more_pure: {True}")
            current_node.left = self._split_data(left_X, left_y, depth+1)
            current_node.right = self._split_data(right_X, right_y, depth+1)
            if current_node.left:
                current_node.has_left = True
            if current_node.right:
                current_node.has_right = True
        else:
            if retry_count == self.max_retry:
                ## 避免一直找不到造成錯誤
                current_node.left = None
                current_node.right = None
                return current_node
            return self._split_data(X, y, depth, retry_count+1)
        return current_node
        
        
    def fit(self, X, y):
        self._split_data(X, y, 0)
    
    def predict(self, X, next_node=None, is_start=True):
        """ 透過Rule搭配boolean matricx快速判斷。 """
        if is_start:
            self.pred = X.copy()
            self.pred['label'] = 0
            current_node = self.root
        else:
            current_node = next_node
        feature = current_node.feature_name
        threshold = current_node.threshold
        value = current_node.value
        
        #print(current_node)
        
        if (not current_node.has_left) and (not current_node.has_right):
            #print(value)
            ## 到了終端節點
            idx = X.index
            self.pred.iloc[idx, -1] = value
            return self.pred.iloc[:, -1]
        
        if current_node.has_left:
            # 有左邊
            X_left = X[X[feature] < threshold]
            self.predict(X_left, current_node.left, False)
        if current_node.has_right:
            # 有右邊
            X_right = X[X[feature] >= threshold]
            self.predict(X_right, current_node.right, False)
        return self.pred.iloc[:, -1]

# %%
# %%time

dt = DecisionTreeRegressorSimple()
dt.fit(X, y)
# Out:
# Wall time: 2min 43s

# %%
dt.predict(X)
# Out:
# 0        4.526000
# 1        3.585000
# 2        3.521000
# 3        3.859667
# 4        3.422000
#            ...
# 20635    0.781000
# 20636    0.771000
# 20637    0.923000
# 20638    0.847000
# 20639    0.894000
# Name: label, Length: 20640, dtype: float64

# %%
dt.pred['true_label'] = y

# %%
for i in range(dt.pred.shape[0]):
    print(f"第{i+1}筆資料, 真實標籤: {dt.pred.iloc[i, -1]}, 預測: {dt.pred.iloc[i, -2]}")
# Out:
# 第1筆資料, 真實標籤: 4.526, 預測: 4.526
# 第2筆資料, 真實標籤: 3.585, 預測: 3.585
# 第3筆資料, 真實標籤: 3.521, 預測: 3.521
# 第4筆資料, 真實標籤: 3.413, 預測: 3.859666666666667
# 第5筆資料, 真實標籤: 3.422, 預測: 3.422
# 第6筆資料, 真實標籤: 2.697, 預測: 2.697
# 第7筆資料, 真實標籤: 2.992, 預測: 2.992
# 第8筆資料, 真實標籤: 2.414, 預測: 2.414
# 第9筆資料, 真實標籤: 2.267, 預測: 2.267
# 第10筆資料, 真實標籤: 2.611, 預測: 2.611
# 第11筆資料, 真實標籤: 2.815, 預測: 2.815
# 第12筆資料, 真實標籤: 2.418, 預測: 2.418
# 第13筆資料, 真實標籤: 2.135, 預測: 2.135
# 第14筆資料, 真實標籤: 1.913, 預測: 2.2936666666666667
# 第15筆資料, 真實標籤: 1.592, 預測: 1.592
# 第16筆資料, 真實標籤: 1.4, 預測: 1.4
# 第17筆資料, 真實標籤: 1.525, 預測: 1.525
# 第18筆資料, 真實標籤: 1.555, 預測: 2.5244400000000002
# 第19筆資料, 真實標籤: 1.587, 預測: 1.587
# 第20筆資料, 真實標籤: 1.629, 預測: 1.629
# 第21筆資料, 真實標籤: 1.475, 預測: 1.475
# 第22筆資料, 真實標籤: 1.598, 預測: 1.598
# 第23筆資料, 真實標籤: 1.139, 預測: 1.139
# 第24筆資料, 真實標籤: 0.997, 預測: 0.997
# 第25筆資料, 真實標籤: 1.326, 預測: 1.326
# 第26筆資料, 真實標籤: 1.075, 預測: 1.075
# 第27筆資料, 真實標籤: 0.938, 預測: 0.938
# 第28筆資料, 真實標籤: 1.055, 預測: 1.055
# 第29筆資料, 真實標籤: 1.089, 預測: 1.089
# 第30筆資料, 真實標籤: 1.32, 預測: 1.32
# 第31筆資料, 真實標籤: 1.223, 預測: 1.223
# 第32筆資料, 真實標籤: 1.152, 預測: 1.152
# 第33筆資料, 真實標籤: 1.104, 預測: 1.104
# 第34筆資料, 真實標籤: 1.049, 預測: 1.049
# 第35筆資料, 真實標籤: 1.097, 預測: 1.097
# 第36筆資料, 真實標籤: 0.972, 預測: 0.972
# 第37筆資料, 真實標籤: 1.045, 預測: 1.045
# 第38筆資料, 真實標籤: 1.039, 預測: 1.039
# 第39筆資料, 真實標籤: 1.914, 預測: 1.914
# 第40筆資料, 真實標籤: 1.76, 預測: 1.76
# 第41筆資料, 真實標籤: 1.554, 預測: 1.554
# 第42筆資料, 真實標籤: 1.5, 預測: 1.5
# 第43筆資料, 真實標籤: 1.188, 預測: 1.188
# 第44筆資料, 真實標籤: 1.888, 預測: 2.45325
# 第45筆資料, 真實標籤: 1.844, 預測: 1.844
# 第46筆資料, 真實標籤: 1.823, 預測: 1.6876000000000002
# 第47筆資料, 真實標籤: 1.425, 預測: 1.425
# 第48筆資料, 真實標籤: 1.375, 預測: 1.375
# 第49筆資料, 真實標籤: 1.875, 預測: 1.875
# 第50筆資料, 真實標籤: 1.125, 預測: 1.125
# 第51筆資料, 真實標籤: 1.719, 預測: 1.719
# 第52筆資料, 真實標籤: 0.938, 預測: 0.938
# 第53筆資料, 真實標籤: 0.975, 預測: 0.975
# 第54筆資料, 真實標籤: 1.042, 預測: 1.042
# 第55筆資料, 真實標籤: 0.875, 預測: 0.875
# 第56筆資料, 真實標籤: 0.831, 預測: 0.831
# 第57筆資料, 真實標籤: 0.875, 預測: 0.875
# 第58筆資料, 真實標籤: 0.853, 預測: 0.853
# 第59筆資料, 真實標籤: 0.803, 預測: 0.803
# 第60筆資料, 真實標籤: 0.6, 預測: 0.6
# 第61筆資料, 真實標籤: 0.757, 預測: 0.757
# 第62筆資料, 真實標籤: 0.75, 預測: 0.75
# 第63筆資料, 真實標籤: 0.861, 預測: 0.861
# 第64筆資料, 真實標籤: 0.761, 預測: 0.761
# 第65筆資料, 真實標籤: 0.735, 預測: 0.735
# 第66筆資料, 真實標籤: 0.784, 預測: 0.784
# 第67筆資料, 真實標籤: 0.844, 預測: 0.844
# 第68筆資料, 真實標籤: 0.813, 預測: 0.813
# 第69筆資料, 真實標籤: 0.85, 預測: 0.85
# 第70筆資料, 真實標籤: 1.292, 預測: 1.292
# 第71筆資料, 真實標籤: 0.825, 預測: 0.825
# 第72筆資料, 真實標籤: 0.952, 預測: 0.952
# 第73筆資料, 真實標籤: 0.75, 預測: 0.75
# 第74筆資料, 真實標籤: 0.675, 預測: 0.675
# 第75筆資料, 真實標籤: 1.375, 預測: 1.375
# 第76筆資料, 真實標籤: 1.775, 預測: 1.775
# 第77筆資料, 真實標籤: 1.021, 預測: 1.021
# 第78筆資料, 真實標籤: 1.083, 預測: 1.0915
# 第79筆資料, 真實標籤: 1.125, 預測: 1.125
# 第80筆資料, 真實標籤: 1.313, 預測: 1.313
# 第81筆資料, 真實標籤: 1.625, 預測: 1.625
# 第82筆資料, 真實標籤: 1.125, 預測: 1.125
# 第83筆資料, 真實標籤: 1.125, 預測: 1.125
# 第84筆資料, 真實標籤: 1.375, 預測: 1.375
# 第85筆資料, 真實標籤: 1.188, 預測: 1.188
# 第86筆資料, 真實標籤: 0.982, 預測: 0.982
# 第87筆資料, 真實標籤: 1.188, 預測: 1.188
# 第88筆資料, 真實標籤: 1.625, 預測: 1.625
# 第89筆資料, 真實標籤: 1.375, 預測: 1.375
# 第90筆資料, 真實標籤: 5.00001, 預測: 2.5244400000000002
# 第91筆資料, 真實標籤: 1.625, 預測: 1.625
# 第92筆資料, 真實標籤: 1.375, 預測: 1.5
# 第93筆資料, 真實標籤: 1.625, 預測: 1.5
# 第94筆資料, 真實標籤: 1.875, 預測: 1.875
# 第95筆資料, 真實標籤: 1.792, 預測: 1.792
# 第96筆資料, 真實標籤: 1.3, 預測: 1.3
# 第97筆資料, 真實標籤: 1.838, 預測: 1.838
# 第98筆資料, 真實標籤: 1.25, 預測: 1.25
# 第99筆資料, 真實標籤: 1.7, 預測: 1.7
# 第100筆資料, 真實標籤: 1.931, 預測: 1.931
# 第101筆資料, 真實標籤: 2.578, 預測: 2.578
# 第102筆資料, 真實標籤: 2.734, 預測: 3.0455
# 第103筆資料, 真實標籤: 2.375, 預測: 2.375
# 第104筆資料, 真實標籤: 3.5, 預測: 3.5
# 第105筆資料, 真實標籤: 3.357, 預測: 3.0455
# 第106筆資料, 真實標籤: 3.134, 預測: 2.7714000000000003
# 第107筆資料, 真實標籤: 2.685, 預測: 2.685
# 第108筆資料, 真實標籤: 2.594, 預測: 2.2936666666666667
# 第109筆資料, 真實標籤: 2.757, 預測: 2.757
# 第110筆資料, 真實標籤: 2.25, 預測: 2.25
# 第111筆資料, 真實標籤: 2.625, 預測: 2.625
# 第112筆資料, 真實標籤: 2.185, 預測: 2.185
# 第113筆資料, 真實標籤: 2.55, 預測: 2.55
# 第114筆資料, 真實標籤: 2.241, 預測: 2.241
# 第115筆資料, 真實標籤: 2.431, 預測: 2.431
# 第116筆資料, 真實標籤: 2.316, 預測: 2.316
# 第117筆資料, 真實標籤: 2.185, 預測: 2.185
# 第118筆資料, 真實標籤: 2.341, 預測: 2.341
# 第119筆資料, 真實標籤: 3.276, 預測: 3.276
# 第120筆資料, 真實標籤: 3.476, 預測: 3.476
# 第121筆資料, 真實標籤: 3.661, 預測: 3.661
# 第122筆資料, 真實標籤: 3.35, 預測: 3.35
# 第123筆資料, 真實標籤: 3.736, 預測: 3.736
# 第124筆資料, 真實標籤: 3.895, 預測: 3.895
# 第125筆資料, 真實標籤: 3.911, 預測: 3.911
# 第126筆資料, 真實標籤: 3.373, 預測: 3.373
# 第127筆資料, 真實標籤: 2.952, 預測: 2.952
# 第128筆資料, 真實標籤: 2.923, 預測: 2.923
# 第129筆資料, 真實標籤: 4.115, 預測: 4.115
# 第130筆資料, 真實標籤: 3.115, 預測: 3.115
# 第131筆資料, 真實標籤: 3.259, 預測: 3.259
# 第132筆資料, 真實標籤: 3.926, 預測: 3.926
# 第133筆資料, 真實標籤: 3.193, 預測: 3.193
# 第134筆資料, 真實標籤: 3.333, 預測: 3.333
# 第135筆資料, 真實標籤: 3.352, 預測: 3.352
# 第136筆資料, 真實標籤: 3.512, 預測: 3.512
# 第137筆資料, 真實標籤: 3.689, 預測: 3.689
# 第138筆資料, 真實標籤: 3.659, 預測: 3.659
# 第139筆資料, 真實標籤: 3.667, 預測: 3.667
# 第140筆資料, 真實標籤: 3.628, 預測: 3.628
# 第141筆資料, 真實標籤: 4.833, 預測: 4.833
# 第142筆資料, 真實標籤: 3.314, 預測: 3.314
# 第143筆資料, 真實標籤: 3.235, 預測: 3.235
# 第144筆資料, 真實標籤: 2.167, 預測: 2.167
# 第145筆資料, 真實標籤: 2.331, 預測: 2.331
# 第146筆資料, 真實標籤: 2.964, 預測: 2.964
# 第147筆資料, 真實標籤: 2.737, 預測: 2.737
# 第148筆資料, 真實標籤: 2.277, 預測: 2.277
# 第149筆資料, 真實標籤: 1.996, 預測: 1.996
# 第150筆資料, 真實標籤: 2.398, 預測: 3.6990049999999997
# 第151筆資料, 真實標籤: 2.701, 預測: 2.701
# 第152筆資料, 真實標籤: 3.021, 預測: 3.021
# 第153筆資料, 真實標籤: 2.695, 預測: 2.695
# 第154筆資料, 真實標籤: 3.147, 預測: 3.147
# 第155筆資料, 真實標籤: 3.901, 預測: 3.901
# 第156筆資料, 真實標籤: 4.103, 預測: 4.103
# 第157筆資料, 真實標籤: 3.524, 預測: 3.524
# 第158筆資料, 真實標籤: 2.873, 預測: 2.7714000000000003
# 第159筆資料, 真實標籤: 3.487, 預測: 3.20875
# 第160筆資料, 真實標籤: 2.438, 預測: 2.438
# 第161筆資料, 真實標籤: 2.115, 預測: 2.115
# 第162筆資料, 真實標籤: 2.184, 預測: 2.5513333333333335
# 第163筆資料, 真實標籤: 2.699, 預測: 2.699
# 第164筆資料, 真實標籤: 2.188, 預測: 2.188
# 第165筆資料, 真實標籤: 2.25, 預測: 2.25
# 第166筆資料, 真實標籤: 2.5, 預測: 2.5
# 第167筆資料, 真實標籤: 1.714, 預測: 1.714
# 第168筆資料, 真實標籤: 1.938, 預測: 1.938
# 第169筆資料, 真實標籤: 1.25, 預測: 1.25
# 第170筆資料, 真實標籤: 0.975, 預測: 0.975
# 第171筆資料, 真實標籤: 1.25, 預測: 1.25
# 第172筆資料, 真實標籤: 1.388, 預測: 1.388
# 第173筆資料, 真實標籤: 1.167, 預測: 1.167
# 第174筆資料, 真實標籤: 1.518, 預測: 1.518
# 第175筆資料, 真實標籤: 1.27, 預測: 1.27
# 第176筆資料, 真實標籤: 1.286, 預測: 1.286
# 第177筆資料, 真實標籤: 1.406, 預測: 1.406
# 第178筆資料, 真實標籤: 1.827, 預測: 1.827
# 第179筆資料, 真實標籤: 1.469, 預測: 1.469
# 第180筆資料, 真實標籤: 1.228, 預測: 1.228
# 第181筆資料, 真實標籤: 1.693, 預測: 1.693
# 第182筆資料, 真實標籤: 1.266, 預測: 2.5244400000000002
# 第183筆資料, 真實標籤: 1.279, 預測: 1.279
# 第184筆資料, 真實標籤: 1.235, 預測: 1.235
# 第185筆資料, 真實標籤: 1.119, 預測: 1.0375
# 第186筆資料, 真實標籤: 1.128, 預測: 1.128
# 第187筆資料, 真實標籤: 1.079, 預測: 1.079
# 第188筆資料, 真實標籤: 1.375, 預測: 1.375
# 第189筆資料, 真實標籤: 1.055, 預測: 1.055
# 第190筆資料, 真實標籤: 0.955, 預測: 0.955
# 第191筆資料, 真實標籤: 1.161, 預測: 2.5244400000000002
# 第192筆資料, 真實標籤: 1.122, 預測: 1.122
# 第193筆資料, 真實標籤: 0.75, 預測: 0.75
# 第194筆資料, 真實標籤: 1.125, 預測: 1.125
# 第195筆資料, 真實標籤: 1.25, 預測: 1.25
# 第196筆資料, 真實標籤: 1.15, 預測: 1.15
# 第197筆資料, 真實標籤: 0.95, 預測: 1.8155000000000001
# 第198筆資料, 真實標籤: 0.964, 預測: 0.964
# 第199筆資料, 真實標籤: 0.72, 預測: 0.72
# 第200筆資料, 真實標籤: 0.713, 預測: 0.713
# 第201筆資料, 真實標籤: 0.808, 預測: 0.808
# 第202筆資料, 真實標籤: 1.288, 預測: 1.288
# 第203筆資料, 真實標籤: 1.125, 預測: 1.125
# 第204筆資料, 真實標籤: 1.194, 預測: 1.194
# 第205筆資料, 真實標籤: 1.181, 預測: 1.181
# 第206筆資料, 真實標籤: 1.225, 預測: 1.225
# 第207筆資料, 真實標籤: 1.063, 預測: 1.063
# 第208筆資料, 真實標籤: 1.325, 預測: 1.325
# 第209筆資料, 真實標籤: 1.227, 預測: 1.227
# 第210筆資料, 真實標籤: 1.133, 預測: 1.133
# 第211筆資料, 真實標籤: 1.095, 預測: 1.095
# 第212筆資料, 真實標籤: 1.647, 預測: 1.647
# 第213筆資料, 真實標籤: 1.25, 預測: 2.5244400000000002
# 第214筆資料, 真實標籤: 1.247, 預測: 1.247
# 第215筆資料, 真實標籤: 1.367, 預測: 1.367
# 第216筆資料, 真實標籤: 1.417, 預測: 1.417
# 第217筆資料, 真實標籤: 1.5, 預測: 1.5
# 第218筆資料, 真實標籤: 1.388, 預測: 1.388
# 第219筆資料, 真實標籤: 1.392, 預測: 1.392
# 第220筆資料, 真實標籤: 1.438, 預測: 1.438
# 第221筆資料, 真實標籤: 1.565, 預測: 1.565
# 第222筆資料, 真實標籤: 1.51, 預測: 1.51
# 第223筆資料, 真實標籤: 2.73, 預測: 2.73
# 第224筆資料, 真實標籤: 2.171, 預測: 2.171
# 第225筆資料, 真實標籤: 1.871, 預測: 1.871
# 第226筆資料, 真實標籤: 2.396, 預測: 2.396
# 第227筆資料, 真實標籤: 2.297, 預測: 2.297
# 第228筆資料, 真實標籤: 2.573, 預測: 2.573
# 第229筆資料, 真實標籤: 2.469, 預測: 2.469
# 第230筆資料, 真實標籤: 1.799, 預測: 1.799
# 第231筆資料, 真實標籤: 1.696, 預測: 1.696
# 第232筆資料, 真實標籤: 2.033, 預測: 2.033
# 第233筆資料, 真實標籤: 2.634, 預測: 2.7714000000000003
# 第234筆資料, 真實標籤: 2.318, 預測: 2.318
# 第235筆資料, 真實標籤: 1.405, 預測: 1.405
# 第236筆資料, 真實標籤: 1.26, 預測: 1.26
# 第237筆資料, 真實標籤: 1.22, 預測: 1.22
# 第238筆資料, 真實標籤: 1.347, 預測: 1.347
# 第239筆資料, 真實標籤: 1.394, 預測: 1.394
# 第240筆資料, 真實標籤: 1.154, 預測: 1.154
# 第241筆資料, 真實標籤: 1.373, 預測: 1.373
# 第242筆資料, 真實標籤: 1.37, 預測: 1.37
# 第243筆資料, 真實標籤: 1.426, 預測: 1.426
# 第244筆資料, 真實標籤: 1.375, 預測: 1.375
# 第245筆資料, 真實標籤: 1.117, 預測: 1.117
# 第246筆資料, 真實標籤: 1.268, 預測: 1.268
# 第247筆資料, 真實標籤: 1.113, 預測: 1.113
# 第248筆資料, 真實標籤: 1.148, 預測: 1.148
# 第249筆資料, 真實標籤: 1.023, 預測: 1.023
# 第250筆資料, 真實標籤: 1.319, 預測: 1.319
# 第251筆資料, 真實標籤: 1.191, 預測: 1.191
# 第252筆資料, 真實標籤: 0.806, 預測: 0.806
# 第253筆資料, 真實標籤: 0.806, 預測: 0.806
# 第254筆資料, 真實標籤: 0.888, 預測: 0.888
# 第255筆資料, 真實標籤: 1.024, 預測: 1.024
# 第256筆資料, 真實標籤: 0.987, 預測: 0.987
# 第257筆資料, 真實標籤: 1.0, 預測: 1.0
# 第258筆資料, 真實標籤: 0.923, 預測: 0.923
# 第259筆資料, 真實標籤: 0.948, 預測: 0.948
# 第260筆資料, 真實標籤: 1.02, 預測: 1.02
# 第261筆資料, 真實標籤: 1.584, 預測: 1.584
# 第262筆資料, 真實標籤: 1.216, 預測: 1.216
# 第263筆資料, 真實標籤: 1.291, 預測: 1.291
# 第264筆資料, 真實標籤: 1.214, 預測: 1.214
# 第265筆資料, 真實標籤: 1.028, 預測: 1.028
# 第266筆資料, 真實標籤: 1.6, 預測: 1.6
# 第267筆資料, 真實標籤: 1.439, 預測: 1.439
# 第268筆資料, 真實標籤: 1.512, 預測: 1.512
# 第269筆資料, 真實標籤: 1.644, 預測: 1.6044999999999998
# 第270筆資料, 真實標籤: 1.565, 預測: 1.6044999999999998
# 第271筆資料, 真實標籤: 2.25, 預測: 2.25
# 第272筆資料, 真實標籤: 1.742, 預測: 1.742
# 第273筆資料, 真實標籤: 1.669, 預測: 1.669
# 第274筆資料, 真實標籤: 1.635, 預測: 1.635
# 第275筆資料, 真實標籤: 2.53, 預測: 2.53
# 第276筆資料, 真實標籤: 2.407, 預測: 2.407
# 第277筆資料, 真實標籤: 2.081, 預測: 2.081
# 第278筆資料, 真實標籤: 1.981, 預測: 1.981
# 第279筆資料, 真實標籤: 1.728, 預測: 1.728
# 第280筆資料, 真實標籤: 3.367, 預測: 1.752744893617021
# 第281筆資料, 真實標籤: 3.182, 預測: 3.182
# 第282筆資料, 真實標籤: 2.858, 預測: 2.858
# 第283筆資料, 真實標籤: 2.93, 預測: 2.93
# 第284筆資料, 真實標籤: 3.71, 預測: 3.71
# 第285筆資料, 真實標籤: 1.573, 預測: 1.573
# 第286筆資料, 真實標籤: 1.353, 預測: 1.353
# 第287筆資料, 真實標籤: 1.367, 預測: 1.367
# 第288筆資料, 真實標籤: 1.607, 預測: 1.607
# 第289筆資料, 真實標籤: 1.406, 預測: 1.406
# 第290筆資料, 真實標籤: 1.44, 預測: 3.2185049999999995
# 第291筆資料, 真實標籤: 1.619, 預測: 1.619
# 第292筆資料, 真實標籤: 1.563, 預測: 1.563
# 第293筆資料, 真實標籤: 1.76, 預測: 1.76
# 第294筆資料, 真實標籤: 1.458, 預測: 1.7296666666666667
# 第295筆資料, 真實標籤: 1.419, 預測: 1.75775
# 第296筆資料, 真實標籤: 0.907, 預測: 0.907
# 第297筆資料, 真實標籤: 0.906, 預測: 0.906
# 第298筆資料, 真實標籤: 1.079, 預測: 1.079
# 第299筆資料, 真實標籤: 1.07, 預測: 1.07
# 第300筆資料, 真實標籤: 0.982, 預測: 0.982
# 第301筆資料, 真實標籤: 0.895, 預測: 0.895
# 第302筆資料, 真實標籤: 0.938, 預測: 0.938
# 第303筆資料, 真實標籤: 0.967, 預測: 0.967
# 第304筆資料, 真實標籤: 0.975, 預測: 0.975
# 第305筆資料, 真實標籤: 0.973, 預測: 0.973
# 第306筆資料, 真實標籤: 0.912, 預測: 0.912
# 第307筆資料, 真實標籤: 0.914, 預測: 0.914
# 第308筆資料, 真實標籤: 0.962, 預測: 0.962
# 第309筆資料, 真實標籤: 1.201, 預測: 1.201
# 第310筆資料, 真實標籤: 1.0, 預測: 1.0
# 第311筆資料, 真實標籤: 0.947, 預測: 0.947
# 第312筆資料, 真實標籤: 0.857, 預測: 0.857
# 第313筆資料, 真實標籤: 0.893, 預測: 0.893
# 第314筆資料, 真實標籤: 1.014, 預測: 1.014
# 第315筆資料, 真實標籤: 0.725, 預測: 0.725
# 第316筆資料, 真實標籤: 0.741, 預測: 0.741
# 第317筆資料, 真實標籤: 0.7, 預測: 0.7
# 第318筆資料, 真實標籤: 0.846, 預測: 0.846
# 第319筆資料, 真實標籤: 0.818, 預測: 0.818
# 第320筆資料, 真實標籤: 0.814, 預測: 0.814
# 第321筆資料, 真實標籤: 0.818, 預測: 0.818
# 第322筆資料, 真實標籤: 0.858, 預測: 0.858
# 第323筆資料, 真實標籤: 0.871, 預測: 0.871
# 第324筆資料, 真實標籤: 0.835, 預測: 0.835
# 第325筆資料, 真實標籤: 0.797, 預測: 0.797
# 第326筆資料, 真實標籤: 0.834, 預測: 0.834
# 第327筆資料, 真實標籤: 0.847, 預測: 0.847
# 第328筆資料, 真實標籤: 0.8, 預測: 0.8
# 第329筆資料, 真實標籤: 0.764, 預測: 0.764
# 第330筆資料, 真實標籤: 0.797, 預測: 0.797
# 第331筆資料, 真實標籤: 0.824, 預測: 0.824
# 第332筆資料, 真實標籤: 0.977, 預測: 0.977
# 第333筆資料, 真實標籤: 0.972, 預測: 0.972
# 第334筆資料, 真實標籤: 1.016, 預測: 1.016
# 第335筆資料, 真實標籤: 0.865, 預測: 0.865
# 第336筆資料, 真實標籤: 0.905, 預測: 0.905
# 第337筆資料, 真實標籤: 1.076, 預測: 1.076
# 第338筆資料, 真實標籤: 0.842, 預測: 0.842
# 第339筆資料, 真實標籤: 0.889, 預測: 0.889
# 第340筆資料, 真實標籤: 0.807, 預測: 0.807
# 第341筆資料, 真實標籤: 0.871, 預測: 0.871
# 第342筆資料, 真實標籤: 0.851, 預測: 0.851
# 第343筆資料, 真實標籤: 0.82, 預測: 0.82
# 第344筆資料, 真實標籤: 0.828, 預測: 0.828
# 第345筆資料, 真實標籤: 0.846, 預測: 0.846
# 第346筆資料, 真實標籤: 0.821, 預測: 0.821
# 第347筆資料, 真實標籤: 0.893, 預測: 0.893
# 第348筆資料, 真實標籤: 0.983, 預測: 0.983
# 第349筆資料, 真實標籤: 0.923, 預測: 0.923
# 第350筆資料, 真實標籤: 0.888, 預測: 0.888
# 第351筆資料, 真實標籤: 0.9, 預測: 0.9
# 第352筆資料, 真實標籤: 0.955, 預測: 1.7045000000000001
# 第353筆資料, 真實標籤: 0.917, 預測: 0.917
# 第354筆資料, 真實標籤: 1.004, 預測: 1.004
# 第355筆資料, 真實標籤: 0.948, 預測: 0.948
# 第356筆資料, 真實標籤: 1.643, 預測: 1.643
# 第357筆資料, 真實標籤: 1.555, 預測: 1.555
# 第358筆資料, 真實標籤: 1.969, 預測: 1.969
# 第359筆資料, 真實標籤: 2.791, 預測: 2.791
# 第360筆資料, 真實標籤: 2.528, 預測: 2.528
# 第361筆資料, 真實標籤: 2.754, 預測: 2.754
# 第362筆資料, 真實標籤: 2.5, 預測: 2.5
# 第363筆資料, 真實標籤: 3.298, 預測: 3.298
# 第364筆資料, 真實標籤: 1.955, 預測: 1.955
# 第365筆資料, 真實標籤: 2.559, 預測: 2.559
# 第366筆資料, 真實標籤: 3.111, 預測: 3.111
# 第367筆資料, 真實標籤: 3.3, 預測: 3.3
# 第368筆資料, 真實標籤: 2.489, 預測: 2.489
# 第369筆資料, 真實標籤: 1.429, 預測: 1.429
# 第370筆資料, 真實標籤: 1.263, 預測: 1.263
# 第371筆資料, 真實標籤: 1.358, 預測: 1.358
# 第372筆資料, 真實標籤: 1.306, 預測: 1.306
# 第373筆資料, 真實標籤: 1.079, 預測: 1.079
# 第374筆資料, 真實標籤: 1.111, 預測: 1.111
# 第375筆資料, 真實標籤: 1.22, 預測: 1.22
# 第376筆資料, 真實標籤: 1.18, 預測: 1.18
# 第377筆資料, 真實標籤: 0.952, 預測: 0.952
# 第378筆資料, 真實標籤: 0.943, 預測: 0.943
# 第379筆資料, 真實標籤: 0.925, 預測: 0.925
# 第380筆資料, 真實標籤: 0.918, 預測: 1.752744893617021
# 第381筆資料, 真實標籤: 1.094, 預測: 1.094
# 第382筆資料, 真實標籤: 1.295, 預測: 1.295
# 第383筆資料, 真實標籤: 1.434, 預測: 3.2185049999999995
# 第384筆資料, 真實標籤: 0.982, 預測: 0.982
# 第385筆資料, 真實標籤: 1.031, 預測: 1.031
# 第386筆資料, 真實標籤: 2.768, 預測: 2.768
# 第387筆資料, 真實標籤: 2.709, 預測: 2.709
# 第388筆資料, 真實標籤: 2.462, 預測: 2.462
# 第389筆資料, 真實標籤: 2.242, 預測: 2.242
# 第390筆資料, 真實標籤: 2.291, 預測: 2.291
# 第391筆資料, 真實標籤: 2.116, 預測: 2.116
# 第392筆資料, 真實標籤: 2.561, 預測: 2.561
# 第393筆資料, 真實標籤: 2.063, 預測: 2.063
# 第394筆資料, 真實標籤: 2.213, 預測: 2.213
# 第395筆資料, 真實標籤: 2.074, 預測: 2.074
# 第396筆資料, 真實標籤: 3.5, 預測: 3.5
# 第397筆資料, 真實標籤: 2.182, 預測: 2.182
# 第398筆資料, 真實標籤: 2.167, 預測: 2.167
# 第399筆資料, 真實標籤: 2.706, 預測: 2.706
# 第400筆資料, 真實標籤: 2.614, 預測: 2.614
# 第401筆資料, 真實標籤: 2.613, 預測: 2.613
# 第402筆資料, 真實標籤: 2.322, 預測: 2.322
# 第403筆資料, 真實標籤: 3.754, 預測: 3.754
# 第404筆資料, 真實標籤: 3.573, 預測: 3.573
# 第405筆資料, 真實標籤: 3.744, 預測: 3.744
# 第406筆資料, 真實標籤: 3.588, 預測: 3.859666666666667
# 第407筆資料, 真實標籤: 4.175, 預測: 4.175
# 第408筆資料, 真實標籤: 4.305, 預測: 4.305
# 第409筆資料, 真實標籤: 3.629, 預測: 4.314505
# 第410筆資料, 真實標籤: 3.97, 預測: 3.97
# 第411筆資料, 真實標籤: 3.468, 預測: 3.468
# 第412筆資料, 真實標籤: 3.271, 預測: 3.271
# 第413筆資料, 真實標籤: 2.901, 預測: 3.079333333333333
# 第414筆資料, 真實標籤: 2.92, 預測: 2.92
# 第415筆資料, 真實標籤: 2.709, 預測: 2.6525
# 第416筆資料, 真實標籤: 3.711, 預測: 3.711
# 第417筆資料, 真實標籤: 3.356, 預測: 3.356
# 第418筆資料, 真實標籤: 3.713, 預測: 3.713
# 第419筆資料, 真實標籤: 3.44, 預測: 3.44
# 第420筆資料, 真實標籤: 3.422, 預測: 3.422
# 第421筆資料, 真實標籤: 3.709, 預測: 3.709
# 第422筆資料, 真實標籤: 3.5, 預測: 3.5
# 第423筆資料, 真實標籤: 3.686, 預測: 3.686
# 第424筆資料, 真實標籤: 3.918, 預測: 3.918
# 第425筆資料, 真實標籤: 4.153, 預測: 3.079333333333333
# 第426筆資料, 真實標籤: 2.849, 預測: 2.849
# 第427筆資料, 真實標籤: 2.875, 預測: 1.6876000000000002
# 第428筆資料, 真實標籤: 2.729, 預測: 2.729
# 第429筆資料, 真實標籤: 2.596, 預測: 2.6525
# 第430筆資料, 真實標籤: 2.545, 預測: 2.545
# 第431筆資料, 真實標籤: 2.356, 預測: 2.45325
# 第432筆資料, 真實標籤: 2.184, 預測: 3.079333333333333
# 第433筆資料, 真實標籤: 2.292, 預測: 2.292
# 第434筆資料, 真實標籤: 1.921, 預測: 1.921
# 第435筆資料, 真實標籤: 1.793, 預測: 1.793
# 第436筆資料, 真實標籤: 1.875, 預測: 1.875
# 第437筆資料, 真實標籤: 1.388, 預測: 2.5244400000000002
# 第438筆資料, 真實標籤: 1.5, 預測: 1.5
# 第439筆資料, 真實標籤: 1.406, 預測: 1.406
# 第440筆資料, 真實標籤: 1.2, 預測: 1.6876000000000002
# 第441筆資料, 真實標籤: 1.448, 預測: 1.448
# 第442筆資料, 真實標籤: 1.448, 預測: 1.448
# 第443筆資料, 真實標籤: 2.455, 預測: 2.455
# 第444筆資料, 真實標籤: 2.0, 預測: 2.0
# 第445筆資料, 真實標籤: 1.737, 預測: 1.737
# 第446筆資料, 真實標籤: 1.856, 預測: 1.856
# 第447筆資料, 真實標籤: 1.826, 預測: 1.826
# 第448筆資料, 真實標籤: 2.279, 預測: 2.279
# 第449筆資料, 真實標籤: 2.207, 預測: 2.207
# 第450筆資料, 真實標籤: 2.12, 預測: 2.12
# 第451筆資料, 真實標籤: 2.714, 預測: 2.714
# 第452筆資料, 真實標籤: 2.688, 預測: 2.688
# 第453筆資料, 真實標籤: 2.778, 預測: 2.778
# 第454筆資料, 真實標籤: 3.325, 預測: 3.325
# 第455筆資料, 真實標籤: 3.389, 預測: 3.389
# 第456筆資料, 真實標籤: 2.875, 預測: 2.875
# 第457筆資料, 真實標籤: 3.846, 預測: 3.846
# 第458筆資料, 真實標籤: 3.714, 預測: 3.714
# 第459筆資料, 真實標籤: 3.5, 預測: 3.5
# 第460筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第461筆資料, 真實標籤: 1.75, 預測: 1.75
# 第462筆資料, 真實標籤: 2.417, 預測: 2.417
# 第463筆資料, 真實標籤: 2.167, 預測: 2.167
# 第464筆資料, 真實標籤: 2.113, 預測: 2.113
# 第465筆資料, 真實標籤: 2.102, 預測: 2.102
# 第466筆資料, 真實標籤: 1.964, 預測: 2.45325
# 第467筆資料, 真實標籤: 1.917, 預測: 1.917
# 第468筆資料, 真實標籤: 1.823, 預測: 2.5244400000000002
# 第469筆資料, 真實標籤: 1.75, 預測: 1.75
# 第470筆資料, 真實標籤: 1.659, 預測: 1.659
# 第471筆資料, 真實標籤: 1.569, 預測: 1.569
# 第472筆資料, 真實標籤: 1.643, 預測: 1.643
# 第473筆資料, 真實標籤: 1.5, 預測: 1.5
# 第474筆資料, 真實標籤: 1.505, 預測: 1.505
# 第475筆資料, 真實標籤: 1.699, 預測: 1.699
# 第476筆資料, 真實標籤: 1.474, 預測: 1.474
# 第477筆資料, 真實標籤: 1.527, 預測: 1.527
# 第478筆資料, 真實標籤: 1.827, 預測: 1.827
# 第479筆資料, 真實標籤: 1.793, 預測: 1.793
# 第480筆資料, 真實標籤: 1.577, 預測: 1.577
# 第481筆資料, 真實標籤: 1.531, 預測: 1.531
# 第482筆資料, 真實標籤: 2.5, 預測: 2.2936666666666667
# 第483筆資料, 真實標籤: 2.063, 預測: 2.063
# 第484筆資料, 真實標籤: 2.188, 預測: 2.188
# 第485筆資料, 真實標籤: 1.982, 預測: 1.982
# 第486筆資料, 真實標籤: 2.536, 預測: 2.536
# 第487筆資料, 真實標籤: 2.574, 預測: 2.574
# 第488筆資料, 真實標籤: 2.895, 預測: 2.895
# 第489筆資料, 真實標籤: 2.417, 預測: 2.417
# 第490筆資料, 真實標籤: 4.896, 預測: 4.896
# 第491筆資料, 真實標籤: 4.462, 預測: 4.462
# 第492筆資料, 真實標籤: 4.563, 預測: 4.563
# 第493筆資料, 真實標籤: 3.368, 預測: 3.368
# 第494筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第495筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第496筆資料, 真實標籤: 3.769, 預測: 3.8775000000000004
# 第497筆資料, 真實標籤: 3.096, 預測: 3.096
# 第498筆資料, 真實標籤: 1.823, 預測: 1.823
# 第499筆資料, 真實標籤: 1.727, 預測: 1.727
# 第500筆資料, 真實標籤: 1.508, 預測: 1.508
# 第501筆資料, 真實標籤: 1.536, 預測: 1.536
# 第502筆資料, 真實標籤: 1.063, 預測: 1.6876000000000002
# 第503筆資料, 真實標籤: 1.423, 預測: 1.423
# 第504筆資料, 真實標籤: 1.194, 預測: 1.6876000000000002
# 第505筆資料, 真實標籤: 1.479, 預測: 1.479
# 第506筆資料, 真實標籤: 1.329, 預測: 1.329
# 第507筆資料, 真實標籤: 1.325, 預測: 1.325
# 第508筆資料, 真實標籤: 1.269, 預測: 1.269
# 第509筆資料, 真實標籤: 1.438, 預測: 1.438
# 第510筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第511筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第512筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第513筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第514筆資料, 真實標籤: 4.661, 預測: 4.661
# 第515筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第516筆資料, 真實標籤: 4.578, 預測: 3.859666666666667
# 第517筆資料, 真實標籤: 4.716, 預測: 3.20875
# 第518筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第519筆資料, 真實標籤: 3.986, 預測: 3.8775000000000004
# 第520筆資料, 真實標籤: 3.407, 預測: 3.407
# 第521筆資料, 真實標籤: 2.899, 預測: 2.899
# 第522筆資料, 真實標籤: 3.353, 預測: 3.353
# 第523筆資料, 真實標籤: 3.33, 預測: 3.33
# 第524筆資料, 真實標籤: 2.41, 預測: 2.41
# 第525筆資料, 真實標籤: 1.896, 預測: 1.896
# 第526筆資料, 真實標籤: 2.063, 預測: 3.20875
# 第527筆資料, 真實標籤: 2.157, 預測: 2.157
# 第528筆資料, 真實標籤: 2.102, 預測: 2.102
# 第529筆資料, 真實標籤: 2.088, 預測: 2.088
# 第530筆資料, 真實標籤: 1.979, 預測: 1.979
# 第531筆資料, 真實標籤: 2.013, 預測: 3.0335
# 第532筆資料, 真實標籤: 1.908, 預測: 1.908
# 第533筆資料, 真實標籤: 2.079, 預測: 2.079
# 第534筆資料, 真實標籤: 2.153, 預測: 2.7714000000000003
# 第535筆資料, 真實標籤: 2.129, 預測: 2.129
# 第536筆資料, 真實標籤: 2.927, 預測: 2.927
# 第537筆資料, 真實標籤: 2.75, 預測: 2.75
# 第538筆資料, 真實標籤: 2.0, 預測: 2.0
# 第539筆資料, 真實標籤: 1.734, 預測: 1.734
# 第540筆資料, 真實標籤: 1.022, 預測: 1.022
# 第541筆資料, 真實標籤: 2.208, 預測: 2.208
# 第542筆資料, 真實標籤: 2.428, 預測: 2.428
# 第543筆資料, 真實標籤: 2.654, 預測: 2.654
# 第544筆資料, 真實標籤: 2.19, 預測: 2.19
# 第545筆資料, 真實標籤: 2.821, 預測: 2.821
# 第546筆資料, 真實標籤: 3.72, 預測: 3.72
# 第547筆資料, 真實標籤: 2.258, 預測: 2.258
# 第548筆資料, 真實標籤: 2.208, 預測: 2.208
# 第549筆資料, 真實標籤: 2.345, 預測: 2.345
# 第550筆資料, 真實標籤: 2.542, 預測: 2.542
# 第551筆資料, 真實標籤: 3.518, 預測: 3.518
# 第552筆資料, 真實標籤: 2.75, 預測: 3.5529999999999995
# 第553筆資料, 真實標籤: 4.054, 預測: 3.0335
# 第554筆資料, 真實標籤: 2.281, 預測: 3.20875
# 第555筆資料, 真實標籤: 2.34, 預測: 2.34
# 第556筆資料, 真實標籤: 1.625, 預測: 1.625
# 第557筆資料, 真實標籤: 2.434, 預測: 2.434
# 第558筆資料, 真實標籤: 2.738, 預測: 2.738
# 第559筆資料, 真實標籤: 2.485, 預測: 2.485
# 第560筆資料, 真實標籤: 2.44, 預測: 2.44
# 第561筆資料, 真實標籤: 2.409, 預測: 2.409
# 第562筆資料, 真實標籤: 3.063, 預測: 2.7714000000000003
# 第563筆資料, 真實標籤: 2.4, 預測: 2.4
# 第564筆資料, 真實標籤: 2.471, 預測: 2.471
# 第565筆資料, 真實標籤: 2.866, 預測: 2.866
# 第566筆資料, 真實標籤: 2.667, 預測: 2.667
# 第567筆資料, 真實標籤: 2.298, 預測: 2.6645000000000003
# 第568筆資料, 真實標籤: 2.293, 預測: 2.293
# 第569筆資料, 真實標籤: 2.284, 預測: 2.284
# 第570筆資料, 真實標籤: 2.062, 預測: 2.062
# 第571筆資料, 真實標籤: 3.507, 預測: 3.507
# 第572筆資料, 真實標籤: 2.31, 預測: 2.31
# 第573筆資料, 真實標籤: 2.529, 預測: 2.529
# 第574筆資料, 真實標籤: 3.539, 預測: 3.539
# 第575筆資料, 真實標籤: 2.917, 預測: 2.917
# 第576筆資料, 真實標籤: 1.0, 預測: 1.0
# 第577筆資料, 真實標籤: 3.416, 預測: 3.416
# 第578筆資料, 真實標籤: 4.125, 預測: 4.125
# 第579筆資料, 真實標籤: 2.486, 預測: 2.486
# 第580筆資料, 真實標籤: 2.549, 預測: 2.549
# 第581筆資料, 真實標籤: 2.415, 預測: 2.415
# 第582筆資料, 真實標籤: 2.952, 預測: 2.952
# 第583筆資料, 真實標籤: 3.404, 預測: 3.404
# 第584筆資料, 真實標籤: 2.747, 預測: 2.747
# 第585筆資料, 真實標籤: 2.386, 預測: 2.386
# 第586筆資料, 真實標籤: 2.664, 預測: 2.664
# 第587筆資料, 真實標籤: 3.302, 預測: 3.302
# 第588筆資料, 真實標籤: 2.068, 預測: 2.068
# 第589筆資料, 真實標籤: 2.092, 預測: 2.092
# 第590筆資料, 真實標籤: 1.958, 預測: 1.958
# 第591筆資料, 真實標籤: 2.535, 預測: 2.5869999999999997
# 第592筆資料, 真實標籤: 2.418, 預測: 2.418
# 第593筆資料, 真實標籤: 2.525, 預測: 2.525
# 第594筆資料, 真實標籤: 2.639, 預測: 2.5869999999999997
# 第595筆資料, 真實標籤: 2.27, 預測: 1.97975
# 第596筆資料, 真實標籤: 2.209, 預測: 2.209
# 第597筆資料, 真實標籤: 2.593, 預測: 2.694
# 第598筆資料, 真實標籤: 2.325, 預測: 2.325
# 第599筆資料, 真實標籤: 2.316, 預測: 1.752744893617021
# 第600筆資料, 真實標籤: 2.094, 預測: 2.094
# 第601筆資料, 真實標籤: 2.232, 預測: 2.232
# 第602筆資料, 真實標籤: 2.099, 預測: 2.099
# 第603筆資料, 真實標籤: 2.082, 預測: 2.082
# 第604筆資料, 真實標籤: 2.038, 預測: 2.038
# 第605筆資料, 真實標籤: 1.957, 預測: 1.957
# 第606筆資料, 真實標籤: 1.905, 預測: 1.905
# 第607筆資料, 真實標籤: 1.81, 預測: 1.81
# 第608筆資料, 真實標籤: 1.849, 預測: 1.849
# 第609筆資料, 真實標籤: 1.908, 預測: 1.908
# 第610筆資料, 真實標籤: 2.422, 預測: 2.422
# 第611筆資料, 真實標籤: 1.883, 預測: 1.883
# 第612筆資料, 真實標籤: 1.835, 預測: 1.835
# 第613筆資料, 真實標籤: 2.042, 預測: 2.042
# 第614筆資料, 真實標籤: 2.519, 預測: 2.519
# 第615筆資料, 真實標籤: 1.875, 預測: 1.875
# 第616筆資料, 真實標籤: 1.982, 預測: 1.982
# 第617筆資料, 真實標籤: 2.19, 預測: 2.19
# 第618筆資料, 真實標籤: 2.75, 預測: 2.75
# 第619筆資料, 真實標籤: 2.454, 預測: 1.7045000000000001
# 第620筆資料, 真實標籤: 1.775, 預測: 1.775
# 第621筆資料, 真實標籤: 1.716, 預測: 1.716
# 第622筆資料, 真實標籤: 1.833, 預測: 1.833
# 第623筆資料, 真實標籤: 1.75, 預測: 1.75
# 第624筆資料, 真實標籤: 1.567, 預測: 1.567
# 第625筆資料, 真實標籤: 1.575, 預測: 1.575
# 第626筆資料, 真實標籤: 1.798, 預測: 1.798
# 第627筆資料, 真實標籤: 2.055, 預測: 2.055
# 第628筆資料, 真實標籤: 1.789, 預測: 1.789
# 第629筆資料, 真實標籤: 2.625, 預測: 2.625
# 第630筆資料, 真實標籤: 1.65, 預測: 1.65
# 第631筆資料, 真實標籤: 1.597, 預測: 1.597
# 第632筆資料, 真實標籤: 1.583, 預測: 1.583
# 第633筆資料, 真實標籤: 1.448, 預測: 1.448
# 第634筆資料, 真實標籤: 1.663, 預測: 1.663
# 第635筆資料, 真實標籤: 1.91, 預測: 1.752744893617021
# 第636筆資料, 真實標籤: 1.75, 預測: 1.75
# 第637筆資料, 真實標籤: 1.375, 預測: 1.375
# 第638筆資料, 真實標籤: 1.417, 預測: 1.417
# 第639筆資料, 真實標籤: 2.109, 預測: 2.109
# 第640筆資料, 真實標籤: 1.983, 預測: 1.983
# 第641筆資料, 真實標籤: 1.574, 預測: 1.574
# 第642筆資料, 真實標籤: 2.647, 預測: 2.647
# 第643筆資料, 真實標籤: 2.184, 預測: 2.184
# 第644筆資料, 真實標籤: 2.351, 預測: 2.351
# 第645筆資料, 真實標籤: 3.418, 預測: 3.418
# 第646筆資料, 真實標籤: 3.673, 預測: 3.673
# 第647筆資料, 真實標籤: 2.435, 預測: 2.435
# 第648筆資料, 真實標籤: 1.679, 預測: 1.679
# 第649筆資料, 真實標籤: 3.712, 預測: 3.712
# 第650筆資料, 真實標籤: 2.189, 預測: 2.189
# 第651筆資料, 真實標籤: 2.027, 預測: 2.027
# 第652筆資料, 真實標籤: 1.862, 預測: 1.862
# 第653筆資料, 真實標籤: 1.889, 預測: 1.889
# 第654筆資料, 真實標籤: 1.8, 預測: 1.8
# 第655筆資料, 真實標籤: 2.027, 預測: 2.027
# 第656筆資料, 真實標籤: 1.817, 預測: 1.817
# 第657筆資料, 真實標籤: 1.668, 預測: 1.9381666666666666
# 第658筆資料, 真實標籤: 1.837, 預測: 1.837
# 第659筆資料, 真實標籤: 2.18, 預測: 2.18
# 第660筆資料, 真實標籤: 1.915, 預測: 1.915
# 第661筆資料, 真實標籤: 1.947, 預測: 1.947
# 第662筆資料, 真實標籤: 1.872, 預測: 1.872
# 第663筆資料, 真實標籤: 2.231, 預測: 2.231
# 第664筆資料, 真實標籤: 2.713, 預測: 2.713
# 第665筆資料, 真實標籤: 1.941, 預測: 1.941
# 第666筆資料, 真實標籤: 1.904, 預測: 1.904
# 第667筆資料, 真實標籤: 1.891, 預測: 1.891
# 第668筆資料, 真實標籤: 1.846, 預測: 1.846
# 第669筆資料, 真實標籤: 1.973, 預測: 1.973
# 第670筆資料, 真實標籤: 1.926, 預測: 1.926
# 第671筆資料, 真實標籤: 1.922, 預測: 1.922
# 第672筆資料, 真實標籤: 1.946, 預測: 1.946
# 第673筆資料, 真實標籤: 1.935, 預測: 1.935
# 第674筆資料, 真實標籤: 2.026, 預測: 2.026
# 第675筆資料, 真實標籤: 0.833, 預測: 0.833
# 第676筆資料, 真實標籤: 2.126, 預測: 2.126
# 第677筆資料, 真實標籤: 1.878, 預測: 1.878
# 第678筆資料, 真實標籤: 2.057, 預測: 2.057
# 第679筆資料, 真實標籤: 1.929, 預測: 1.929
# 第680筆資料, 真實標籤: 2.052, 預測: 2.052
# 第681筆資料, 真實標籤: 2.134, 預測: 2.134
# 第682筆資料, 真實標籤: 1.836, 預測: 1.836
# 第683筆資料, 真實標籤: 1.784, 預測: 1.784
# 第684筆資料, 真實標籤: 2.192, 預測: 2.192
# 第685筆資料, 真實標籤: 1.831, 預測: 1.831
# 第686筆資料, 真實標籤: 1.571, 預測: 1.571
# 第687筆資料, 真實標籤: 1.578, 預測: 1.578
# 第688筆資料, 真實標籤: 1.617, 預測: 1.617
# 第689筆資料, 真實標籤: 1.521, 預測: 1.521
# 第690筆資料, 真實標籤: 1.449, 預測: 1.449
# 第691筆資料, 真實標籤: 1.799, 預測: 1.799
# 第692筆資料, 真實標籤: 1.791, 預測: 1.791
# 第693筆資料, 真實標籤: 1.599, 預測: 1.599
# 第694筆資料, 真實標籤: 1.614, 預測: 1.614
# 第695筆資料, 真實標籤: 1.704, 預測: 1.704
# 第696筆資料, 真實標籤: 1.375, 預測: 1.375
# 第697筆資料, 真實標籤: 1.784, 預測: 1.784
# 第698筆資料, 真實標籤: 1.552, 預測: 1.552
# 第699筆資料, 真實標籤: 1.609, 預測: 1.609
# 第700筆資料, 真實標籤: 1.673, 預測: 1.673
# 第701筆資料, 真實標籤: 3.4, 預測: 3.4
# 第702筆資料, 真實標籤: 4.31, 預測: 4.31
# 第703筆資料, 真實標籤: 3.011, 預測: 3.011
# 第704筆資料, 真實標籤: 2.419, 預測: 2.419
# 第705筆資料, 真實標籤: 1.625, 預測: 1.625
# 第706筆資料, 真實標籤: 2.992, 預測: 2.992
# 第707筆資料, 真實標籤: 3.155, 預測: 3.155
# 第708筆資料, 真實標籤: 2.168, 預測: 2.168
# 第709筆資料, 真實標籤: 2.181, 預測: 2.181
# 第710筆資料, 真實標籤: 1.703, 預測: 1.703
# 第711筆資料, 真實標籤: 2.75, 預測: 2.75
# 第712筆資料, 真實標籤: 1.841, 預測: 1.841
# 第713筆資料, 真實標籤: 1.6, 預測: 1.6
# 第714筆資料, 真實標籤: 1.75, 預測: 1.75
# 第715筆資料, 真實標籤: 1.975, 預測: 1.975
# 第716筆資料, 真實標籤: 1.5, 預測: 1.2354
# 第717筆資料, 真實標籤: 2.056, 預測: 2.056
# 第718筆資料, 真實標籤: 1.703, 預測: 1.703
# 第719筆資料, 真實標籤: 1.909, 預測: 1.909
# 第720筆資料, 真實標籤: 1.969, 預測: 1.752744893617021
# 第721筆資料, 真實標籤: 1.74, 預測: 1.74
# 第722筆資料, 真實標籤: 1.702, 預測: 1.702
# 第723筆資料, 真實標籤: 1.809, 預測: 1.809
# 第724筆資料, 真實標籤: 1.505, 預測: 1.505
# 第725筆資料, 真實標籤: 1.671, 預測: 1.671
# 第726筆資料, 真實標籤: 1.489, 預測: 1.489
# 第727筆資料, 真實標籤: 1.964, 預測: 1.964
# 第728筆資料, 真實標籤: 1.911, 預測: 1.911
# 第729筆資料, 真實標籤: 1.875, 預測: 1.875
# 第730筆資料, 真實標籤: 1.806, 預測: 1.806
# 第731筆資料, 真實標籤: 1.828, 預測: 1.828
# 第732筆資料, 真實標籤: 1.793, 預測: 1.793
# 第733筆資料, 真實標籤: 1.794, 預測: 1.794
# 第734筆資料, 真實標籤: 2.103, 預測: 2.103
# 第735筆資料, 真實標籤: 1.923, 預測: 1.923
# 第736筆資料, 真實標籤: 1.981, 預測: 1.981
# 第737筆資料, 真實標籤: 1.962, 預測: 1.962
# 第738筆資料, 真實標籤: 1.816, 預測: 1.816
# 第739筆資料, 真實標籤: 1.869, 預測: 1.869
# 第740筆資料, 真實標籤: 1.883, 預測: 1.883
# 第741筆資料, 真實標籤: 1.84, 預測: 1.84
# 第742筆資料, 真實標籤: 1.847, 預測: 1.847
# 第743筆資料, 真實標籤: 1.799, 預測: 1.799
# 第744筆資料, 真實標籤: 1.672, 預測: 1.672
# 第745筆資料, 真實標籤: 1.654, 預測: 1.654
# 第746筆資料, 真實標籤: 1.54, 預測: 1.54
# 第747筆資料, 真實標籤: 1.535, 預測: 1.535
# 第748筆資料, 真實標籤: 1.354, 預測: 1.354
# 第749筆資料, 真實標籤: 1.583, 預測: 1.583
# 第750筆資料, 真實標籤: 2.407, 預測: 2.407
# 第751筆資料, 真實標籤: 1.807, 預測: 1.807
# 第752筆資料, 真實標籤: 2.306, 預測: 2.306
# 第753筆資料, 真實標籤: 2.108, 預測: 2.108
# 第754筆資料, 真實標籤: 1.653, 預測: 1.653
# 第755筆資料, 真實標籤: 2.542, 預測: 2.542
# 第756筆資料, 真實標籤: 3.326, 預測: 3.326
# 第757筆資料, 真實標籤: 3.5, 預測: 3.5
# 第758筆資料, 真實標籤: 1.612, 預測: 1.612
# 第759筆資料, 真實標籤: 1.793, 預測: 1.793
# 第760筆資料, 真實標籤: 1.543, 預測: 1.543
# 第761筆資料, 真實標籤: 1.618, 預測: 1.618
# 第762筆資料, 真實標籤: 1.619, 預測: 1.619
# 第763筆資料, 真實標籤: 1.654, 預測: 1.654
# 第764筆資料, 真實標籤: 1.666, 預測: 1.666
# 第765筆資料, 真實標籤: 1.497, 預測: 1.752744893617021
# 第766筆資料, 真實標籤: 1.621, 預測: 1.621
# 第767筆資料, 真實標籤: 1.526, 預測: 1.526
# 第768筆資料, 真實標籤: 1.952, 預測: 1.952
# 第769筆資料, 真實標籤: 1.906, 預測: 1.906
# 第770筆資料, 真實標籤: 1.938, 預測: 1.938
# 第771筆資料, 真實標籤: 2.006, 預測: 2.006
# 第772筆資料, 真實標籤: 1.5, 預測: 1.5
# 第773筆資料, 真實標籤: 1.853, 預測: 1.853
# 第774筆資料, 真實標籤: 1.727, 預測: 1.727
# 第775筆資料, 真實標籤: 1.741, 預測: 1.741
# 第776筆資料, 真實標籤: 1.944, 預測: 1.944
# 第777筆資料, 真實標籤: 2.067, 預測: 2.067
# 第778筆資料, 真實標籤: 2.045, 預測: 2.045
# 第779筆資料, 真實標籤: 1.75, 預測: 1.75
# 第780筆資料, 真實標籤: 1.375, 預測: 1.375
# 第781筆資料, 真實標籤: 1.872, 預測: 1.872
# 第782筆資料, 真實標籤: 1.736, 預測: 1.736
# 第783筆資料, 真實標籤: 1.63, 預測: 1.63
# 第784筆資料, 真實標籤: 3.316, 預測: 3.316
# 第785筆資料, 真實標籤: 1.976, 預測: 1.976
# 第786筆資料, 真實標籤: 1.979, 預測: 1.979
# 第787筆資料, 真實標籤: 2.281, 預測: 2.281
# 第788筆資料, 真實標籤: 1.895, 預測: 2.1205
# 第789筆資料, 真實標籤: 1.842, 預測: 1.842
# 第790筆資料, 真實標籤: 1.809, 預測: 1.809
# 第791筆資料, 真實標籤: 1.72, 預測: 1.72
# 第792筆資料, 真實標籤: 1.779, 預測: 2.4234999999999998
# 第793筆資料, 真實標籤: 1.731, 預測: 1.731
# 第794筆資料, 真實標籤: 1.726, 預測: 1.726
# 第795筆資料, 真實標籤: 1.821, 預測: 2.4154999999999998
# 第796筆資料, 真實標籤: 1.795, 預測: 1.795
# 第797筆資料, 真實標籤: 1.76, 預測: 1.76
# 第798筆資料, 真實標籤: 1.926, 預測: 1.926
# 第799筆資料, 真實標籤: 1.827, 預測: 1.827
# 第800筆資料, 真實標籤: 1.349, 預測: 1.349
# 第801筆資料, 真實標籤: 1.576, 預測: 1.576
# 第802筆資料, 真實標籤: 1.909, 預測: 1.909
# 第803筆資料, 真實標籤: 1.582, 預測: 2.0945
# 第804筆資料, 真實標籤: 3.5, 預測: 3.5
# 第805筆資料, 真實標籤: 1.582, 預測: 1.582
# 第806筆資料, 真實標籤: 1.461, 預測: 1.461
# 第807筆資料, 真實標籤: 2.267, 預測: 2.267
# 第808筆資料, 真實標籤: 1.987, 預測: 1.987
# 第809筆資料, 真實標籤: 2.212, 預測: 2.212
# 第810筆資料, 真實標籤: 2.085, 預測: 1.9945
# 第811筆資料, 真實標籤: 2.042, 預測: 2.042
# 第812筆資料, 真實標籤: 1.932, 預測: 1.932
# 第813筆資料, 真實標籤: 2.095, 預測: 2.095
# 第814筆資料, 真實標籤: 1.649, 預測: 1.649
# 第815筆資料, 真實標籤: 1.614, 預測: 1.752744893617021
# 第816筆資料, 真實標籤: 1.87, 預測: 1.87
# 第817筆資料, 真實標籤: 1.904, 預測: 1.9945
# 第818筆資料, 真實標籤: 1.566, 預測: 1.566
# 第819筆資料, 真實標籤: 1.573, 預測: 1.573
# 第820筆資料, 真實標籤: 1.681, 預測: 1.681
# 第821筆資料, 真實標籤: 1.776, 預測: 1.776
# 第822筆資料, 真實標籤: 2.089, 預測: 2.089
# 第823筆資料, 真實標籤: 1.692, 預測: 1.692
# 第824筆資料, 真實標籤: 1.639, 預測: 1.639
# 第825筆資料, 真實標籤: 1.647, 預測: 1.647
# 第826筆資料, 真實標籤: 1.569, 預測: 1.569
# 第827筆資料, 真實標籤: 1.688, 預測: 1.688
# 第828筆資料, 真實標籤: 1.741, 預測: 1.741
# 第829筆資料, 真實標籤: 2.065, 預測: 2.065
# 第830筆資料, 真實標籤: 2.039, 預測: 2.039
# 第831筆資料, 真實標籤: 2.17, 預測: 2.17
# 第832筆資料, 真實標籤: 1.596, 預測: 1.596
# 第833筆資料, 真實標籤: 1.598, 預測: 1.598
# 第834筆資料, 真實標籤: 1.543, 預測: 1.543
# 第835筆資料, 真實標籤: 1.496, 預測: 1.496
# 第836筆資料, 真實標籤: 1.886, 預測: 1.886
# 第837筆資料, 真實標籤: 2.385, 預測: 2.385
# 第838筆資料, 真實標籤: 2.353, 預測: 2.353
# 第839筆資料, 真實標籤: 2.614, 預測: 2.614
# 第840筆資料, 真實標籤: 2.344, 預測: 2.344
# 第841筆資料, 真實標籤: 2.317, 預測: 2.317
# 第842筆資料, 真實標籤: 1.563, 預測: 1.563
# 第843筆資料, 真實標籤: 2.22, 預測: 2.22
# 第844筆資料, 真實標籤: 2.544, 預測: 2.4545000000000003
# 第845筆資料, 真實標籤: 2.443, 預測: 2.559
# 第846筆資料, 真實標籤: 2.47, 預測: 2.47
# 第847筆資料, 真實標籤: 2.365, 預測: 2.4545000000000003
# 第848筆資料, 真實標籤: 1.514, 預測: 1.514
# 第849筆資料, 真實標籤: 2.137, 預測: 2.137
# 第850筆資料, 真實標籤: 2.436, 預測: 2.436
# 第851筆資料, 真實標籤: 2.125, 預測: 2.125
# 第852筆資料, 真實標籤: 2.147, 預測: 2.147
# 第853筆資料, 真實標籤: 2.132, 預測: 2.132
# 第854筆資料, 真實標籤: 2.56, 預測: 2.56
# 第855筆資料, 真實標籤: 2.375, 預測: 2.375
# 第856筆資料, 真實標籤: 1.781, 預測: 1.781
# 第857筆資料, 真實標籤: 2.318, 預測: 2.318
# 第858筆資料, 真實標籤: 1.479, 預測: 1.479
# 第859筆資料, 真實標籤: 1.917, 預測: 1.917
# 第860筆資料, 真實標籤: 2.476, 預測: 2.476
# 第861筆資料, 真實標籤: 2.835, 預測: 2.835
# 第862筆資料, 真實標籤: 2.169, 預測: 2.169
# 第863筆資料, 真實標籤: 2.825, 預測: 2.825
# 第864筆資料, 真實標籤: 2.956, 預測: 2.956
# 第865筆資料, 真實標籤: 2.818, 預測: 2.818
# 第866筆資料, 真實標籤: 2.698, 預測: 2.698
# 第867筆資料, 真實標籤: 2.312, 預測: 2.312
# 第868筆資料, 真實標籤: 3.183, 預測: 3.183
# 第869筆資料, 真實標籤: 2.534, 預測: 2.534
# 第870筆資料, 真實標籤: 2.782, 預測: 2.782
# 第871筆資料, 真實標籤: 3.0, 預測: 3.0
# 第872筆資料, 真實標籤: 2.735, 預測: 2.735
# 第873筆資料, 真實標籤: 2.234, 預測: 2.234
# 第874筆資料, 真實標籤: 2.145, 預測: 2.145
# 第875筆資料, 真實標籤: 2.202, 預測: 2.202
# 第876筆資料, 真實標籤: 2.403, 預測: 2.403
# 第877筆資料, 真實標籤: 1.58, 預測: 1.58
# 第878筆資料, 真實標籤: 2.242, 預測: 2.242
# 第879筆資料, 真實標籤: 1.772, 預測: 1.772
# 第880筆資料, 真實標籤: 2.161, 預測: 2.161
# 第881筆資料, 真實標籤: 2.697, 預測: 2.697
# 第882筆資料, 真實標籤: 2.312, 預測: 2.312
# 第883筆資料, 真實標籤: 1.625, 預測: 1.625
# 第884筆資料, 真實標籤: 2.54, 預測: 2.54
# 第885筆資料, 真實標籤: 1.962, 預測: 1.962
# 第886筆資料, 真實標籤: 1.894, 預測: 1.894
# 第887筆資料, 真實標籤: 2.208, 預測: 2.208
# 第888筆資料, 真實標籤: 2.138, 預測: 2.138
# 第889筆資料, 真實標籤: 4.429, 預測: 4.429
# 第890筆資料, 真實標籤: 3.334, 預測: 3.334
# 第891筆資料, 真實標籤: 3.524, 預測: 3.524
# 第892筆資料, 真實標籤: 3.053, 預測: 3.0069999999999997
# 第893筆資料, 真實標籤: 2.596, 預測: 2.596
# 第894筆資料, 真實標籤: 2.489, 預測: 2.489
# 第895筆資料, 真實標籤: 3.56, 預測: 3.56
# 第896筆資料, 真實標籤: 2.36, 預測: 2.36
# 第897筆資料, 真實標籤: 2.188, 預測: 2.188
# 第898筆資料, 真實標籤: 2.28, 預測: 2.28
# 第899筆資料, 真實標籤: 2.359, 預測: 2.359
# 第900筆資料, 真實標籤: 2.032, 預測: 2.032
# 第901筆資料, 真實標籤: 1.97, 預測: 1.97
# 第902筆資料, 真實標籤: 2.364, 預測: 2.364
# 第903筆資料, 真實標籤: 2.232, 預測: 2.232
# 第904筆資料, 真實標籤: 2.227, 預測: 2.227
# 第905筆資料, 真實標籤: 2.25, 預測: 2.2439999999999998
# 第906筆資料, 真實標籤: 2.401, 預測: 2.401
# 第907筆資料, 真實標籤: 2.279, 預測: 2.279
# 第908筆資料, 真實標籤: 2.686, 預測: 2.686
# 第909筆資料, 真實標籤: 2.751, 預測: 2.751
# 第910筆資料, 真實標籤: 2.563, 預測: 2.563
# 第911筆資料, 真實標籤: 3.324, 預測: 3.324
# 第912筆資料, 真實標籤: 2.876, 預測: 2.876
# 第913筆資料, 真實標籤: 2.989, 預測: 2.989
# 第914筆資料, 真實標籤: 2.876, 預測: 2.876
# 第915筆資料, 真實標籤: 2.222, 預測: 2.222
# 第916筆資料, 真實標籤: 2.326, 預測: 2.326
# 第917筆資料, 真實標籤: 2.583, 預測: 2.583
# 第918筆資料, 真實標籤: 2.309, 預測: 2.309
# 第919筆資料, 真實標籤: 1.969, 預測: 1.969
# 第920筆資料, 真實標籤: 2.235, 預測: 2.235
# 第921筆資料, 真實標籤: 2.239, 預測: 2.239
# 第922筆資料, 真實標籤: 2.435, 預測: 2.435
# 第923筆資料, 真實標籤: 4.511, 預測: 4.511
# 第924筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第925筆資料, 真實標籤: 1.931, 預測: 1.931
# 第926筆資料, 真實標籤: 2.644, 預測: 2.644
# 第927筆資料, 真實標籤: 2.469, 預測: 2.469
# 第928筆資料, 真實標籤: 3.373, 預測: 3.373
# 第929筆資料, 真實標籤: 2.848, 預測: 2.848
# 第930筆資料, 真實標籤: 2.173, 預測: 2.173
# 第931筆資料, 真實標籤: 2.917, 預測: 2.917
# 第932筆資料, 真實標籤: 2.238, 預測: 2.2439999999999998
# 第933筆資料, 真實標籤: 2.231, 預測: 2.231
# 第934筆資料, 真實標籤: 2.113, 預測: 2.113
# 第935筆資料, 真實標籤: 2.185, 預測: 2.185
# 第936筆資料, 真實標籤: 1.563, 預測: 1.563
# 第937筆資料, 真實標籤: 2.482, 預測: 2.482
# 第938筆資料, 真實標籤: 1.86, 預測: 1.86
# 第939筆資料, 真實標籤: 1.782, 預測: 1.782
# 第940筆資料, 真實標籤: 1.904, 預測: 1.904
# 第941筆資料, 真實標籤: 2.103, 預測: 2.103
# 第942筆資料, 真實標籤: 2.08, 預測: 2.08
# 第943筆資料, 真實標籤: 1.833, 預測: 1.833
# 第944筆資料, 真實標籤: 2.457, 預測: 2.457
# 第945筆資料, 真實標籤: 2.422, 預測: 2.422
# 第946筆資料, 真實標籤: 1.817, 預測: 1.817
# 第947筆資料, 真實標籤: 2.994, 預測: 2.994
# 第948筆資料, 真實標籤: 2.195, 預測: 2.195
# 第949筆資料, 真實標籤: 2.318, 預測: 2.318
# 第950筆資料, 真實標籤: 2.213, 預測: 2.213
# 第951筆資料, 真實標籤: 2.138, 預測: 2.138
# 第952筆資料, 真實標籤: 2.06, 預測: 2.06
# 第953筆資料, 真實標籤: 2.711, 預測: 2.711
# 第954筆資料, 真實標籤: 3.365, 預測: 3.365
# 第955筆資料, 真實標籤: 3.156, 預測: 3.156
# 第956筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第957筆資料, 真實標籤: 2.854, 預測: 2.854
# 第958筆資料, 真實標籤: 3.23, 預測: 3.23
# 第959筆資料, 真實標籤: 2.919, 預測: 2.919
# 第960筆資料, 真實標籤: 2.256, 預測: 2.256
# 第961筆資料, 真實標籤: 2.596, 預測: 2.673
# 第962筆資料, 真實標籤: 2.629, 預測: 2.629
# 第963筆資料, 真實標籤: 2.573, 預測: 2.573
# 第964筆資料, 真實標籤: 2.592, 預測: 2.592
# 第965筆資料, 真實標籤: 3.397, 預測: 3.397
# 第966筆資料, 真實標籤: 3.372, 預測: 3.372
# 第967筆資料, 真實標籤: 3.341, 預測: 3.341
# 第968筆資料, 真實標籤: 3.115, 預測: 3.115
# 第969筆資料, 真實標籤: 2.969, 預測: 2.969
# 第970筆資料, 真實標籤: 2.479, 預測: 2.479
# 第971筆資料, 真實標籤: 3.004, 預測: 3.004
# 第972筆資料, 真實標籤: 3.324, 預測: 3.324
# 第973筆資料, 真實標籤: 3.898, 預測: 3.898
# 第974筆資料, 真實標籤: 2.33, 預測: 2.33
# 第975筆資料, 真實標籤: 2.385, 預測: 2.385
# 第976筆資料, 真實標籤: 2.333, 預測: 2.333
# 第977筆資料, 真實標籤: 2.313, 預測: 2.313
# 第978筆資料, 真實標籤: 4.758, 預測: 4.758
# 第979筆資料, 真實標籤: 3.932, 預測: 3.932
# 第980筆資料, 真實標籤: 2.472, 預測: 2.472
# 第981筆資料, 真實標籤: 2.294, 預測: 2.294
# 第982筆資料, 真實標籤: 2.825, 預測: 2.825
# 第983筆資料, 真實標籤: 3.006, 預測: 3.006
# 第984筆資料, 真實標籤: 2.932, 預測: 2.932
# 第985筆資料, 真實標籤: 2.785, 預測: 2.785
# 第986筆資料, 真實標籤: 3.529, 預測: 3.529
# 第987筆資料, 真實標籤: 4.0, 預測: 4.0
# 第988筆資料, 真實標籤: 3.75, 預測: 3.75
# 第989筆資料, 真實標籤: 3.137, 預測: 3.137
# 第990筆資料, 真實標籤: 1.393, 預測: 1.393
# 第991筆資料, 真實標籤: 3.275, 預測: 3.275
# 第992筆資料, 真實標籤: 4.306, 預測: 4.306
# 第993筆資料, 真實標籤: 1.25, 預測: 1.25
# 第994筆資料, 真實標籤: 4.5, 預測: 4.5
# 第995筆資料, 真實標籤: 2.002, 預測: 2.002
# 第996筆資料, 真實標籤: 1.924, 預測: 1.924
# 第997筆資料, 真實標籤: 4.188, 預測: 4.188
# 第998筆資料, 真實標籤: 2.168, 預測: 2.168
# 第999筆資料, 真實標籤: 2.155, 預測: 2.155
# 第1000筆資料, 真實標籤: 2.277, 預測: 2.277
# 第1001筆資料, 真實標籤: 1.844, 預測: 1.844
# 第1002筆資料, 真實標籤: 1.584, 預測: 1.584
# 第1003筆資料, 真實標籤: 1.746, 預測: 1.746
# 第1004筆資料, 真實標籤: 1.684, 預測: 1.684
# 第1005筆資料, 真實標籤: 1.884, 預測: 1.884
# 第1006筆資料, 真實標籤: 2.567, 預測: 2.567
# 第1007筆資料, 真實標籤: 1.838, 預測: 1.838
# 第1008筆資料, 真實標籤: 1.834, 預測: 1.834
# 第1009筆資料, 真實標籤: 1.775, 預測: 1.775
# 第1010筆資料, 真實標籤: 1.869, 預測: 1.869
# 第1011筆資料, 真實標籤: 2.389, 預測: 2.389
# 第1012筆資料, 真實標籤: 1.725, 預測: 1.725
# 第1013筆資料, 真實標籤: 1.792, 預測: 1.792
# 第1014筆資料, 真實標籤: 2.044, 預測: 2.044
# 第1015筆資料, 真實標籤: 2.094, 預測: 2.094
# 第1016筆資料, 真實標籤: 2.642, 預測: 2.642
# 第1017筆資料, 真實標籤: 3.5, 預測: 3.5
# 第1018筆資料, 真實標籤: 1.998, 預測: 1.998
# 第1019筆資料, 真實標籤: 2.11, 預測: 2.11
# 第1020筆資料, 真實標籤: 2.011, 預測: 2.011
# 第1021筆資料, 真實標籤: 1.93, 預測: 1.93
# 第1022筆資料, 真實標籤: 2.45, 預測: 2.45
# 第1023筆資料, 真實標籤: 1.176, 預測: 1.176
# 第1024筆資料, 真實標籤: 0.979, 預測: 0.979
# 第1025筆資料, 真實標籤: 1.406, 預測: 1.406
# 第1026筆資料, 真實標籤: 1.209, 預測: 1.209
# 第1027筆資料, 真實標籤: 1.19, 預測: 1.19
# 第1028筆資料, 真實標籤: 1.292, 預測: 1.4245
# 第1029筆資料, 真實標籤: 0.991, 預測: 0.991
# 第1030筆資料, 真實標籤: 1.089, 預測: 1.089
# 第1031筆資料, 真實標籤: 1.117, 預測: 1.117
# 第1032筆資料, 真實標籤: 0.689, 預測: 0.689
# 第1033筆資料, 真實標籤: 0.964, 預測: 1.1616666666666668
# 第1034筆資料, 真實標籤: 1.167, 預測: 1.167
# 第1035筆資料, 真實標籤: 1.238, 預測: 1.238
# 第1036筆資料, 真實標籤: 0.979, 預測: 0.979
# 第1037筆資料, 真實標籤: 1.298, 預測: 1.298
# 第1038筆資料, 真實標籤: 1.213, 預測: 1.213
# 第1039筆資料, 真實標籤: 1.072, 預測: 1.072
# 第1040筆資料, 真實標籤: 1.219, 預測: 1.219
# 第1041筆資料, 真實標籤: 1.134, 預測: 1.134
# 第1042筆資料, 真實標籤: 0.991, 預測: 0.991
# 第1043筆資料, 真實標籤: 1.03, 預測: 1.03
# 第1044筆資料, 真實標籤: 1.142, 預測: 1.142
# 第1045筆資料, 真實標籤: 1.441, 預測: 1.441
# 第1046筆資料, 真實標籤: 1.286, 預測: 1.286
# 第1047筆資料, 真實標籤: 1.572, 預測: 1.9264666666666668
# 第1048筆資料, 真實標籤: 1.185, 預測: 1.185
# 第1049筆資料, 真實標籤: 1.167, 預測: 1.167
# 第1050筆資料, 真實標籤: 1.348, 預測: 1.348
# 第1051筆資料, 真實標籤: 1.099, 預測: 1.099
# 第1052筆資料, 真實標籤: 1.443, 預測: 1.443
# 第1053筆資料, 真實標籤: 1.236, 預測: 2.113571428571429
# 第1054筆資料, 真實標籤: 1.126, 預測: 1.126
# 第1055筆資料, 真實標籤: 1.073, 預測: 1.073
# 第1056筆資料, 真實標籤: 1.178, 預測: 1.178
# 第1057筆資料, 真實標籤: 0.899, 預測: 0.899
# 第1058筆資料, 真實標籤: 1.023, 預測: 1.023
# 第1059筆資料, 真實標籤: 0.873, 預測: 0.873
# 第1060筆資料, 真實標籤: 1.426, 預測: 1.426
# 第1061筆資料, 真實標籤: 1.531, 預測: 1.531
# 第1062筆資料, 真實標籤: 1.266, 預測: 1.266
# 第1063筆資料, 真實標籤: 1.183, 預測: 1.7071999999999998
# 第1064筆資料, 真實標籤: 1.47, 預測: 1.47
# 第1065筆資料, 真實標籤: 0.781, 預測: 0.781
# 第1066筆資料, 真實標籤: 0.858, 預測: 0.858
# 第1067筆資料, 真實標籤: 0.845, 預測: 0.845
# 第1068筆資料, 真實標籤: 1.375, 預測: 1.375
# 第1069筆資料, 真實標籤: 0.889, 預測: 0.889
# 第1070筆資料, 真實標籤: 1.202, 預測: 1.202
# 第1071筆資料, 真實標籤: 0.745, 預測: 0.745
# 第1072筆資料, 真實標籤: 0.851, 預測: 0.851
# 第1073筆資料, 真實標籤: 1.303, 預測: 1.303
# 第1074筆資料, 真實標籤: 1.252, 預測: 1.252
# 第1075筆資料, 真實標籤: 1.114, 預測: 1.114
# 第1076筆資料, 真實標籤: 0.97, 預測: 0.97
# 第1077筆資料, 真實標籤: 1.226, 預測: 1.226
# 第1078筆資料, 真實標籤: 1.163, 預測: 1.163
# 第1079筆資料, 真實標籤: 1.792, 預測: 1.792
# 第1080筆資料, 真實標籤: 0.858, 預測: 0.858
# 第1081筆資料, 真實標籤: 0.948, 預測: 0.948
# 第1082筆資料, 真實標籤: 2.0, 預測: 2.0
# 第1083筆資料, 真實標籤: 1.125, 預測: 1.125
# 第1084筆資料, 真實標籤: 0.69, 預測: 0.69
# 第1085筆資料, 真實標籤: 0.55, 預測: 0.55
# 第1086筆資料, 真實標籤: 0.779, 預測: 1.6876000000000002
# 第1087筆資料, 真實標籤: 0.988, 預測: 0.988
# 第1088筆資料, 真實標籤: 0.787, 預測: 0.787
# 第1089筆資料, 真實標籤: 0.813, 預測: 0.813
# 第1090筆資料, 真實標籤: 0.603, 預測: 0.603
# 第1091筆資料, 真實標籤: 0.663, 預測: 0.663
# 第1092筆資料, 真實標籤: 1.167, 預測: 1.167
# 第1093筆資料, 真實標籤: 1.597, 預測: 1.597
# 第1094筆資料, 真實標籤: 1.392, 預測: 1.392
# 第1095筆資料, 真實標籤: 0.896, 預測: 0.896
# 第1096筆資料, 真實標籤: 1.531, 預測: 1.531
# 第1097筆資料, 真實標籤: 0.875, 預測: 0.875
# 第1098筆資料, 真實標籤: 1.586, 預測: 1.586
# 第1099筆資料, 真實標籤: 0.951, 預測: 0.951
# 第1100筆資料, 真實標籤: 0.938, 預測: 0.938
# 第1101筆資料, 真實標籤: 0.953, 預測: 0.953
# 第1102筆資料, 真實標籤: 1.413, 預測: 1.413
# 第1103筆資料, 真實標籤: 0.675, 預測: 0.675
# 第1104筆資料, 真實標籤: 0.73, 預測: 0.73
# 第1105筆資料, 真實標籤: 1.196, 預測: 0.985
# 第1106筆資料, 真實標籤: 0.932, 預測: 0.932
# 第1107筆資料, 真實標籤: 1.179, 預測: 1.179
# 第1108筆資料, 真實標籤: 0.972, 預測: 0.972
# 第1109筆資料, 真實標籤: 0.976, 預測: 0.976
# 第1110筆資料, 真實標籤: 0.953, 預測: 0.953
# 第1111筆資料, 真實標籤: 1.077, 預測: 1.077
# 第1112筆資料, 真實標籤: 1.029, 預測: 1.029
# 第1113筆資料, 真實標籤: 0.883, 預測: 0.883
# 第1114筆資料, 真實標籤: 0.865, 預測: 0.961
# 第1115筆資料, 真實標籤: 0.58, 預測: 0.58
# 第1116筆資料, 真實標籤: 0.84, 預測: 0.84
# 第1117筆資料, 真實標籤: 0.895, 預測: 0.895
# 第1118筆資料, 真實標籤: 0.934, 預測: 0.934
# 第1119筆資料, 真實標籤: 1.152, 預測: 1.152
# 第1120筆資料, 真實標籤: 1.057, 預測: 0.961
# 第1121筆資料, 真實標籤: 0.973, 預測: 0.973
# 第1122筆資料, 真實標籤: 1.086, 預測: 1.086
# 第1123筆資料, 真實標籤: 1.049, 預測: 1.049
# 第1124筆資料, 真實標籤: 1.102, 預測: 1.102
# 第1125筆資料, 真實標籤: 1.038, 預測: 1.038
# 第1126筆資料, 真實標籤: 0.808, 預測: 0.808
# 第1127筆資料, 真實標籤: 0.873, 預測: 0.873
# 第1128筆資料, 真實標籤: 0.855, 預測: 0.6765
# 第1129筆資料, 真實標籤: 0.85, 預測: 0.85
# 第1130筆資料, 真實標籤: 0.935, 預測: 0.935
# 第1131筆資料, 真實標籤: 0.967, 預測: 0.967
# 第1132筆資料, 真實標籤: 1.097, 預測: 1.097
# 第1133筆資料, 真實標籤: 0.858, 預測: 0.858
# 第1134筆資料, 真實標籤: 0.928, 預測: 0.928
# 第1135筆資料, 真實標籤: 0.705, 預測: 1.752744893617021
# 第1136筆資料, 真實標籤: 1.218, 預測: 1.218
# 第1137筆資料, 真實標籤: 1.026, 預測: 1.026
# 第1138筆資料, 真實標籤: 1.012, 預測: 1.012
# 第1139筆資料, 真實標籤: 1.683, 預測: 1.683
# 第1140筆資料, 真實標籤: 1.261, 預測: 1.261
# 第1141筆資料, 真實標籤: 0.838, 預測: 0.838
# 第1142筆資料, 真實標籤: 0.926, 預測: 0.926
# 第1143筆資料, 真實標籤: 1.112, 預測: 1.112
# 第1144筆資料, 真實標籤: 0.875, 預測: 0.875
# 第1145筆資料, 真實標籤: 0.875, 預測: 0.875
# 第1146筆資料, 真實標籤: 0.947, 預測: 0.947
# 第1147筆資料, 真實標籤: 0.625, 預測: 0.625
# 第1148筆資料, 真實標籤: 0.833, 預測: 0.833
# 第1149筆資料, 真實標籤: 0.857, 預測: 0.857
# 第1150筆資料, 真實標籤: 0.795, 預測: 0.795
# 第1151筆資料, 真實標籤: 0.536, 預測: 0.536
# 第1152筆資料, 真實標籤: 0.652, 預測: 0.652
# 第1153筆資料, 真實標籤: 0.841, 預測: 0.841
# 第1154筆資料, 真實標籤: 1.423, 預測: 1.423
# 第1155筆資料, 真實標籤: 0.938, 預測: 0.938
# 第1156筆資料, 真實標籤: 0.908, 預測: 0.908
# 第1157筆資料, 真實標籤: 0.918, 預測: 0.918
# 第1158筆資料, 真實標籤: 0.975, 預測: 0.975
# 第1159筆資料, 真實標籤: 0.912, 預測: 0.912
# 第1160筆資料, 真實標籤: 0.738, 預測: 0.738
# 第1161筆資料, 真實標籤: 0.864, 預測: 0.864
# 第1162筆資料, 真實標籤: 0.621, 預測: 0.621
# 第1163筆資料, 真實標籤: 0.722, 預測: 0.722
# 第1164筆資料, 真實標籤: 0.576, 預測: 0.576
# 第1165筆資料, 真實標籤: 0.583, 預測: 0.583
# 第1166筆資料, 真實標籤: 0.517, 預測: 0.517
# 第1167筆資料, 真實標籤: 0.579, 預測: 0.579
# 第1168筆資料, 真實標籤: 0.531, 預測: 0.531
# 第1169筆資料, 真實標籤: 0.561, 預測: 0.561
# 第1170筆資料, 真實標籤: 0.58, 預測: 0.58
# 第1171筆資料, 真實標籤: 0.567, 預測: 0.567
# 第1172筆資料, 真實標籤: 0.576, 預測: 0.576
# 第1173筆資料, 真實標籤: 0.633, 預測: 0.633
# 第1174筆資料, 真實標籤: 0.598, 預測: 0.598
# 第1175筆資料, 真實標籤: 0.652, 預測: 0.652
# 第1176筆資料, 真實標籤: 0.425, 預測: 0.425
# 第1177筆資料, 真實標籤: 0.451, 預測: 0.451
# 第1178筆資料, 真實標籤: 0.394, 預測: 0.394
# 第1179筆資料, 真實標籤: 0.503, 預測: 0.503
# 第1180筆資料, 真實標籤: 0.538, 預測: 0.538
# 第1181筆資料, 真實標籤: 0.539, 預測: 0.539
# 第1182筆資料, 真實標籤: 0.418, 預測: 0.418
# 第1183筆資料, 真實標籤: 0.889, 預測: 0.889
# 第1184筆資料, 真實標籤: 0.826, 預測: 0.826
# 第1185筆資料, 真實標籤: 0.636, 預測: 0.7244999999999999
# 第1186筆資料, 真實標籤: 0.594, 預測: 0.594
# 第1187筆資料, 真實標籤: 0.606, 預測: 0.606
# 第1188筆資料, 真實標籤: 0.571, 預測: 0.571
# 第1189筆資料, 真實標籤: 0.49, 預測: 0.49
# 第1190筆資料, 真實標籤: 0.804, 預測: 0.804
# 第1191筆資料, 真實標籤: 0.962, 預測: 0.962
# 第1192筆資料, 真實標籤: 0.6, 預測: 0.6
# 第1193筆資料, 真實標籤: 0.613, 預測: 0.613
# 第1194筆資料, 真實標籤: 0.738, 預測: 0.738
# 第1195筆資料, 真實標籤: 0.863, 預測: 0.863
# 第1196筆資料, 真實標籤: 0.864, 預測: 0.864
# 第1197筆資料, 真實標籤: 0.846, 預測: 0.846
# 第1198筆資料, 真實標籤: 0.735, 預測: 0.735
# 第1199筆資料, 真實標籤: 0.562, 預測: 0.562
# 第1200筆資料, 真實標籤: 0.57, 預測: 0.57
# 第1201筆資料, 真實標籤: 0.639, 預測: 0.639
# 第1202筆資料, 真實標籤: 0.56, 預測: 0.56
# 第1203筆資料, 真實標籤: 0.63, 預測: 0.63
# 第1204筆資料, 真實標籤: 0.855, 預測: 0.855
# 第1205筆資料, 真實標籤: 0.813, 預測: 0.7244999999999999
# 第1206筆資料, 真實標籤: 0.576, 預測: 0.576
# 第1207筆資料, 真實標籤: 0.594, 預測: 0.594
# 第1208筆資料, 真實標籤: 0.819, 預測: 0.819
# 第1209筆資料, 真實標籤: 0.821, 預測: 0.821
# 第1210筆資料, 真實標籤: 1.16, 預測: 1.16
# 第1211筆資料, 真實標籤: 1.161, 預測: 1.161
# 第1212筆資料, 真實標籤: 0.949, 預測: 0.949
# 第1213筆資料, 真實標籤: 0.922, 預測: 0.922
# 第1214筆資料, 真實標籤: 0.799, 預測: 0.799
# 第1215筆資料, 真實標籤: 1.33, 預測: 1.33
# 第1216筆資料, 真實標籤: 1.226, 預測: 1.226
# 第1217筆資料, 真實標籤: 0.904, 預測: 0.904
# 第1218筆資料, 真實標籤: 0.932, 預測: 0.932
# 第1219筆資料, 真實標籤: 1.259, 預測: 1.259
# 第1220筆資料, 真實標籤: 1.331, 預測: 1.331
# 第1221筆資料, 真實標籤: 1.306, 預測: 1.306
# 第1222筆資料, 真實標籤: 1.04, 預測: 1.04
# 第1223筆資料, 真實標籤: 1.016, 預測: 1.016
# 第1224筆資料, 真實標籤: 0.926, 預測: 0.926
# 第1225筆資料, 真實標籤: 1.223, 預測: 1.223
# 第1226筆資料, 真實標籤: 1.125, 預測: 1.125
# 第1227筆資料, 真實標籤: 0.866, 預測: 0.866
# 第1228筆資料, 真實標籤: 0.774, 預測: 0.774
# 第1229筆資料, 真實標籤: 0.919, 預測: 0.919
# 第1230筆資料, 真實標籤: 1.009, 預測: 1.009
# 第1231筆資料, 真實標籤: 0.947, 預測: 0.947
# 第1232筆資料, 真實標籤: 0.848, 預測: 0.848
# 第1233筆資料, 真實標籤: 1.399, 預測: 1.399
# 第1234筆資料, 真實標籤: 1.214, 預測: 1.214
# 第1235筆資料, 真實標籤: 1.558, 預測: 1.292
# 第1236筆資料, 真實標籤: 1.115, 預測: 1.115
# 第1237筆資料, 真實標籤: 1.235, 預測: 1.292
# 第1238筆資料, 真實標籤: 1.137, 預測: 1.137
# 第1239筆資料, 真實標籤: 1.038, 預測: 1.038
# 第1240筆資料, 真實標籤: 1.083, 預測: 1.292
# 第1241筆資料, 真實標籤: 0.775, 預測: 0.775
# 第1242筆資料, 真實標籤: 0.658, 預測: 0.658
# 第1243筆資料, 真實標籤: 0.675, 預測: 0.675
# 第1244筆資料, 真實標籤: 0.592, 預測: 0.592
# 第1245筆資料, 真實標籤: 0.72, 預測: 0.72
# 第1246筆資料, 真實標籤: 0.928, 預測: 0.928
# 第1247筆資料, 真實標籤: 1.125, 預測: 1.125
# 第1248筆資料, 真實標籤: 0.75, 預測: 0.75
# 第1249筆資料, 真實標籤: 1.08, 預測: 1.08
# 第1250筆資料, 真實標籤: 0.655, 預測: 0.655
# 第1251筆資料, 真實標籤: 0.615, 預測: 0.615
# 第1252筆資料, 真實標籤: 0.627, 預測: 0.627
# 第1253筆資料, 真實標籤: 0.688, 預測: 0.688
# 第1254筆資料, 真實標籤: 0.691, 預測: 0.691
# 第1255筆資料, 真實標籤: 0.758, 預測: 0.758
# 第1256筆資料, 真實標籤: 0.75, 預測: 0.75
# 第1257筆資料, 真實標籤: 1.125, 預測: 1.125
# 第1258筆資料, 真實標籤: 1.924, 預測: 1.924
# 第1259筆資料, 真實標籤: 2.094, 預測: 2.094
# 第1260筆資料, 真實標籤: 1.838, 預測: 1.838
# 第1261筆資料, 真實標籤: 1.891, 預測: 1.891
# 第1262筆資料, 真實標籤: 1.565, 預測: 1.565
# 第1263筆資料, 真實標籤: 1.688, 預測: 1.688
# 第1264筆資料, 真實標籤: 1.628, 預測: 1.628
# 第1265筆資料, 真實標籤: 1.729, 預測: 1.729
# 第1266筆資料, 真實標籤: 1.297, 預測: 1.297
# 第1267筆資料, 真實標籤: 2.135, 預測: 2.135
# 第1268筆資料, 真實標籤: 1.194, 預測: 1.194
# 第1269筆資料, 真實標籤: 1.311, 預測: 1.311
# 第1270筆資料, 真實標籤: 1.254, 預測: 1.254
# 第1271筆資料, 真實標籤: 1.514, 預測: 1.514
# 第1272筆資料, 真實標籤: 2.631, 預測: 2.631
# 第1273筆資料, 真實標籤: 1.871, 預測: 1.871
# 第1274筆資料, 真實標籤: 1.567, 預測: 1.567
# 第1275筆資料, 真實標籤: 1.863, 預測: 1.863
# 第1276筆資料, 真實標籤: 1.525, 預測: 1.525
# 第1277筆資料, 真實標籤: 2.414, 預測: 2.414
# 第1278筆資料, 真實標籤: 3.409, 預測: 3.409
# 第1279筆資料, 真實標籤: 1.544, 預測: 1.544
# 第1280筆資料, 真實標籤: 2.539, 預測: 2.539
# 第1281筆資料, 真實標籤: 1.094, 預測: 1.094
# 第1282筆資料, 真實標籤: 1.051, 預測: 1.051
# 第1283筆資料, 真實標籤: 1.285, 預測: 1.285
# 第1284筆資料, 真實標籤: 0.938, 預測: 0.938
# 第1285筆資料, 真實標籤: 0.991, 預測: 0.991
# 第1286筆資料, 真實標籤: 0.964, 預測: 0.964
# 第1287筆資料, 真實標籤: 1.27, 預測: 1.27
# 第1288筆資料, 真實標籤: 0.875, 預測: 0.875
# 第1289筆資料, 真實標籤: 1.339, 預測: 1.339
# 第1290筆資料, 真實標籤: 1.468, 預測: 1.468
# 第1291筆資料, 真實標籤: 1.247, 預測: 1.247
# 第1292筆資料, 真實標籤: 1.102, 預測: 1.102
# 第1293筆資料, 真實標籤: 1.308, 預測: 1.308
# 第1294筆資料, 真實標籤: 1.745, 預測: 1.745
# 第1295筆資料, 真實標籤: 1.681, 預測: 1.681
# 第1296筆資料, 真實標籤: 1.704, 預測: 1.704
# 第1297筆資料, 真實標籤: 1.508, 預測: 1.508
# 第1298筆資料, 真實標籤: 1.652, 預測: 1.652
# 第1299筆資料, 真實標籤: 0.935, 預測: 0.935
# 第1300筆資料, 真實標籤: 1.134, 預測: 1.134
# 第1301筆資料, 真實標籤: 0.973, 預測: 0.973
# 第1302筆資料, 真實標籤: 1.31, 預測: 1.31
# 第1303筆資料, 真實標籤: 1.334, 預測: 1.334
# 第1304筆資料, 真實標籤: 1.0, 預測: 1.0
# 第1305筆資料, 真實標籤: 1.036, 預測: 1.036
# 第1306筆資料, 真實標籤: 1.453, 預測: 1.453
# 第1307筆資料, 真實標籤: 1.524, 預測: 1.189
# 第1308筆資料, 真實標籤: 1.459, 預測: 1.459
# 第1309筆資料, 真實標籤: 1.425, 預測: 1.425
# 第1310筆資料, 真實標籤: 0.758, 預測: 0.758
# 第1311筆資料, 真實標籤: 1.261, 預測: 1.261
# 第1312筆資料, 真實標籤: 1.426, 預測: 1.426
# 第1313筆資料, 真實標籤: 1.647, 預測: 1.647
# 第1314筆資料, 真實標籤: 1.085, 預測: 0.9103333333333333
# 第1315筆資料, 真實標籤: 1.786, 預測: 1.786
# 第1316筆資料, 真實標籤: 1.647, 預測: 1.647
# 第1317筆資料, 真實標籤: 1.225, 預測: 1.225
# 第1318筆資料, 真實標籤: 1.795, 預測: 1.795
# 第1319筆資料, 真實標籤: 2.051, 預測: 2.051
# 第1320筆資料, 真實標籤: 1.586, 預測: 1.586
# 第1321筆資料, 真實標籤: 0.902, 預測: 0.902
# 第1322筆資料, 真實標籤: 0.675, 預測: 0.675
# 第1323筆資料, 真實標籤: 0.994, 預測: 0.994
# 第1324筆資料, 真實標籤: 1.014, 預測: 1.014
# 第1325筆資料, 真實標籤: 0.877, 預測: 0.877
# 第1326筆資料, 真實標籤: 0.87, 預測: 0.87
# 第1327筆資料, 真實標籤: 0.946, 預測: 0.946
# 第1328筆資料, 真實標籤: 1.818, 預測: 1.818
# 第1329筆資料, 真實標籤: 1.178, 預測: 1.178
# 第1330筆資料, 真實標籤: 1.403, 預測: 1.403
# 第1331筆資料, 真實標籤: 1.5, 預測: 1.5
# 第1332筆資料, 真實標籤: 1.344, 預測: 1.344
# 第1333筆資料, 真實標籤: 1.519, 預測: 1.519
# 第1334筆資料, 真實標籤: 1.652, 預測: 1.652
# 第1335筆資料, 真實標籤: 1.617, 預測: 1.617
# 第1336筆資料, 真實標籤: 1.705, 預測: 1.705
# 第1337筆資料, 真實標籤: 1.742, 預測: 1.742
# 第1338筆資料, 真實標籤: 1.441, 預測: 1.441
# 第1339筆資料, 真實標籤: 1.639, 預測: 1.639
# 第1340筆資料, 真實標籤: 1.039, 預測: 1.039
# 第1341筆資料, 真實標籤: 1.222, 預測: 1.222
# 第1342筆資料, 真實標籤: 1.36, 預測: 1.36
# 第1343筆資料, 真實標籤: 1.565, 預測: 1.565
# 第1344筆資料, 真實標籤: 0.992, 預測: 0.992
# 第1345筆資料, 真實標籤: 1.106, 預測: 1.106
# 第1346筆資料, 真實標籤: 1.622, 預測: 1.622
# 第1347筆資料, 真實標籤: 1.775, 預測: 1.775
# 第1348筆資料, 真實標籤: 1.66, 預測: 1.66
# 第1349筆資料, 真實標籤: 1.608, 預測: 1.608
# 第1350筆資料, 真實標籤: 1.548, 預測: 1.548
# 第1351筆資料, 真實標籤: 1.431, 預測: 1.431
# 第1352筆資料, 真實標籤: 0.871, 預測: 0.871
# 第1353筆資料, 真實標籤: 0.953, 預測: 0.953
# 第1354筆資料, 真實標籤: 1.007, 預測: 1.007
# 第1355筆資料, 真實標籤: 1.139, 預測: 1.139
# 第1356筆資料, 真實標籤: 1.002, 預測: 1.002
# 第1357筆資料, 真實標籤: 1.25, 預測: 1.25
# 第1358筆資料, 真實標籤: 1.298, 預測: 1.298
# 第1359筆資料, 真實標籤: 0.835, 預測: 0.835
# 第1360筆資料, 真實標籤: 1.398, 預測: 1.398
# 第1361筆資料, 真實標籤: 0.985, 預測: 0.985
# 第1362筆資料, 真實標籤: 1.569, 預測: 1.569
# 第1363筆資料, 真實標籤: 1.659, 預測: 1.659
# 第1364筆資料, 真實標籤: 1.339, 預測: 1.339
# 第1365筆資料, 真實標籤: 2.25, 預測: 2.25
# 第1366筆資料, 真實標籤: 1.66, 預測: 1.66
# 第1367筆資料, 真實標籤: 1.448, 預測: 1.448
# 第1368筆資料, 真實標籤: 1.783, 預測: 1.783
# 第1369筆資料, 真實標籤: 1.393, 預測: 1.393
# 第1370筆資料, 真實標籤: 1.508, 預測: 1.508
# 第1371筆資料, 真實標籤: 1.961, 預測: 1.961
# 第1372筆資料, 真實標籤: 1.161, 預測: 1.161
# 第1373筆資料, 真實標籤: 1.294, 預測: 1.294
# 第1374筆資料, 真實標籤: 1.664, 預測: 1.664
# 第1375筆資料, 真實標籤: 1.265, 預測: 1.265
# 第1376筆資料, 真實標籤: 1.357, 預測: 1.357
# 第1377筆資料, 真實標籤: 1.724, 預測: 1.724
# 第1378筆資料, 真實標籤: 1.137, 預測: 1.137
# 第1379筆資料, 真實標籤: 1.597, 預測: 1.597
# 第1380筆資料, 真實標籤: 1.563, 預測: 2.113571428571429
# 第1381筆資料, 真實標籤: 2.042, 預測: 2.042
# 第1382筆資料, 真實標籤: 2.126, 預測: 2.126
# 第1383筆資料, 真實標籤: 1.999, 預測: 1.999
# 第1384筆資料, 真實標籤: 2.054, 預測: 2.054
# 第1385筆資料, 真實標籤: 2.067, 預測: 2.067
# 第1386筆資料, 真實標籤: 2.877, 預測: 2.877
# 第1387筆資料, 真實標籤: 2.452, 預測: 2.452
# 第1388筆資料, 真實標籤: 2.941, 預測: 2.941
# 第1389筆資料, 真實標籤: 2.973, 預測: 2.973
# 第1390筆資料, 真實標籤: 2.11, 預測: 2.11
# 第1391筆資料, 真實標籤: 2.254, 預測: 2.254
# 第1392筆資料, 真實標籤: 2.696, 預測: 2.696
# 第1393筆資料, 真實標籤: 2.282, 預測: 2.282
# 第1394筆資料, 真實標籤: 2.355, 預測: 2.355
# 第1395筆資料, 真實標籤: 1.669, 預測: 1.669
# 第1396筆資料, 真實標籤: 1.861, 預測: 1.861
# 第1397筆資料, 真實標籤: 2.118, 預測: 2.118
# 第1398筆資料, 真實標籤: 1.971, 預測: 1.971
# 第1399筆資料, 真實標籤: 1.896, 預測: 1.752744893617021
# 第1400筆資料, 真實標籤: 2.66, 預測: 2.66
# 第1401筆資料, 真實標籤: 1.864, 預測: 1.864
# 第1402筆資料, 真實標籤: 1.9, 預測: 1.9
# 第1403筆資料, 真實標籤: 2.43, 預測: 2.43
# 第1404筆資料, 真實標籤: 2.356, 預測: 2.356
# 第1405筆資料, 真實標籤: 1.962, 預測: 2.113571428571429
# 第1406筆資料, 真實標籤: 1.82, 預測: 1.82
# 第1407筆資料, 真實標籤: 1.694, 預測: 1.694
# 第1408筆資料, 真實標籤: 1.793, 預測: 1.793
# 第1409筆資料, 真實標籤: 2.357, 預測: 2.357
# 第1410筆資料, 真實標籤: 2.051, 預測: 2.051
# 第1411筆資料, 真實標籤: 2.208, 預測: 2.208
# 第1412筆資料, 真實標籤: 2.332, 預測: 2.332
# 第1413筆資料, 真實標籤: 2.321, 預測: 2.321
# 第1414筆資料, 真實標籤: 2.657, 預測: 2.657
# 第1415筆資料, 真實標籤: 2.479, 預測: 2.479
# 第1416筆資料, 真實標籤: 2.732, 預測: 2.732
# 第1417筆資料, 真實標籤: 0.911, 預測: 0.911
# 第1418筆資料, 真實標籤: 1.345, 預測: 1.345
# 第1419筆資料, 真實標籤: 1.362, 預測: 1.362
# 第1420筆資料, 真實標籤: 2.5, 預測: 2.5
# 第1421筆資料, 真實標籤: 0.875, 預測: 0.875
# 第1422筆資料, 真實標籤: 1.375, 預測: 1.375
# 第1423筆資料, 真實標籤: 1.364, 預測: 1.364
# 第1424筆資料, 真實標籤: 0.75, 預測: 0.75
# 第1425筆資料, 真實標籤: 1.563, 預測: 1.563
# 第1426筆資料, 真實標籤: 1.406, 預測: 1.406
# 第1427筆資料, 真實標籤: 1.783, 預測: 1.783
# 第1428筆資料, 真實標籤: 1.759, 預測: 1.759
# 第1429筆資料, 真實標籤: 1.399, 預測: 1.399
# 第1430筆資料, 真實標籤: 1.382, 預測: 1.382
# 第1431筆資料, 真實標籤: 1.782, 預測: 1.782
# 第1432筆資料, 真實標籤: 1.693, 預測: 1.693
# 第1433筆資料, 真實標籤: 1.619, 預測: 1.619
# 第1434筆資料, 真實標籤: 1.666, 預測: 1.752744893617021
# 第1435筆資料, 真實標籤: 1.489, 預測: 1.489
# 第1436筆資料, 真實標籤: 1.655, 預測: 1.655
# 第1437筆資料, 真實標籤: 1.94, 預測: 1.94
# 第1438筆資料, 真實標籤: 2.269, 預測: 2.269
# 第1439筆資料, 真實標籤: 2.028, 預測: 2.028
# 第1440筆資料, 真實標籤: 2.115, 預測: 2.115
# 第1441筆資料, 真實標籤: 1.655, 預測: 1.655
# 第1442筆資料, 真實標籤: 1.617, 預測: 1.752744893617021
# 第1443筆資料, 真實標籤: 1.923, 預測: 1.923
# 第1444筆資料, 真實標籤: 1.932, 預測: 1.932
# 第1445筆資料, 真實標籤: 1.84, 預測: 1.84
# 第1446筆資料, 真實標籤: 2.172, 預測: 2.172
# 第1447筆資料, 真實標籤: 1.82, 預測: 1.82
# 第1448筆資料, 真實標籤: 1.613, 預測: 1.613
# 第1449筆資料, 真實標籤: 1.61, 預測: 1.61
# 第1450筆資料, 真實標籤: 1.449, 預測: 1.449
# 第1451筆資料, 真實標籤: 2.595, 預測: 2.595
# 第1452筆資料, 真實標籤: 2.105, 預測: 2.105
# 第1453筆資料, 真實標籤: 2.441, 預測: 2.441
# 第1454筆資料, 真實標籤: 1.848, 預測: 1.848
# 第1455筆資料, 真實標籤: 2.292, 預測: 2.292
# 第1456筆資料, 真實標籤: 1.961, 預測: 1.961
# 第1457筆資料, 真實標籤: 2.041, 預測: 2.041
# 第1458筆資料, 真實標籤: 2.402, 預測: 2.402
# 第1459筆資料, 真實標籤: 2.311, 預測: 2.311
# 第1460筆資料, 真實標籤: 2.132, 預測: 2.132
# 第1461筆資料, 真實標籤: 2.072, 預測: 2.072
# 第1462筆資料, 真實標籤: 1.841, 預測: 1.841
# 第1463筆資料, 真實標籤: 1.79, 預測: 1.79
# 第1464筆資料, 真實標籤: 1.907, 預測: 1.907
# 第1465筆資料, 真實標籤: 1.678, 預測: 1.678
# 第1466筆資料, 真實標籤: 2.467, 預測: 2.467
# 第1467筆資料, 真實標籤: 1.267, 預測: 1.267
# 第1468筆資料, 真實標籤: 2.604, 預測: 2.604
# 第1469筆資料, 真實標籤: 2.006, 預測: 2.006
# 第1470筆資料, 真實標籤: 2.674, 預測: 2.674
# 第1471筆資料, 真實標籤: 2.659, 預測: 2.659
# ...
# 第20174筆資料, 真實標籤: 2.794, 預測: 2.794
# 第20175筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20176筆資料, 真實標籤: 2.592, 預測: 2.592
# 第20177筆資料, 真實標籤: 2.242, 預測: 2.242
# 第20178筆資料, 真實標籤: 2.682, 預測: 2.682
# 第20179筆資料, 真實標籤: 2.832, 預測: 2.832
# 第20180筆資料, 真實標籤: 1.757, 預測: 1.757
# 第20181筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20182筆資料, 真實標籤: 2.25, 預測: 2.25
# 第20183筆資料, 真實標籤: 1.542, 預測: 1.542
# 第20184筆資料, 真實標籤: 2.192, 預測: 2.192
# 第20185筆資料, 真實標籤: 2.327, 預測: 2.613
# 第20186筆資料, 真實標籤: 2.211, 預測: 2.211
# 第20187筆資料, 真實標籤: 0.75, 預測: 0.75
# 第20188筆資料, 真實標籤: 2.795, 預測: 2.795
# 第20189筆資料, 真實標籤: 2.348, 預測: 2.5105
# 第20190筆資料, 真實標籤: 2.365, 預測: 2.365
# 第20191筆資料, 真實標籤: 2.673, 預測: 2.5105
# 第20192筆資料, 真實標籤: 2.236, 預測: 2.236
# 第20193筆資料, 真實標籤: 0.55, 預測: 0.55
# 第20194筆資料, 真實標籤: 1.573, 預測: 1.573
# 第20195筆資料, 真實標籤: 1.452, 預測: 1.452
# 第20196筆資料, 真實標籤: 2.034, 預測: 2.114
# 第20197筆資料, 真實標籤: 2.176, 預測: 2.176
# 第20198筆資料, 真實標籤: 1.995, 預測: 1.995
# 第20199筆資料, 真實標籤: 2.18, 預測: 2.18
# 第20200筆資料, 真實標籤: 2.289, 預測: 2.289
# 第20201筆資料, 真實標籤: 2.146, 預測: 2.146
# 第20202筆資料, 真實標籤: 2.341, 預測: 2.341
# 第20203筆資料, 真實標籤: 2.232, 預測: 2.232
# 第20204筆資料, 真實標籤: 2.35, 預測: 2.35
# 第20205筆資料, 真實標籤: 1.875, 預測: 1.875
# 第20206筆資料, 真實標籤: 2.194, 預測: 2.114
# 第20207筆資料, 真實標籤: 2.343, 預測: 2.343
# 第20208筆資料, 真實標籤: 2.293, 預測: 2.293
# 第20209筆資料, 真實標籤: 4.093, 預測: 4.093
# 第20210筆資料, 真實標籤: 2.811, 預測: 2.811
# 第20211筆資料, 真實標籤: 4.043, 預測: 3.9074999999999998
# 第20212筆資料, 真實標籤: 3.036, 預測: 3.036
# 第20213筆資料, 真實標籤: 2.997, 預測: 2.997
# 第20214筆資料, 真實標籤: 2.575, 預測: 2.575
# 第20215筆資料, 真實標籤: 2.319, 預測: 2.319
# 第20216筆資料, 真實標籤: 2.541, 預測: 2.0765000000000002
# 第20217筆資料, 真實標籤: 3.964, 預測: 3.964
# 第20218筆資料, 真實標籤: 3.032, 預測: 3.032
# 第20219筆資料, 真實標籤: 2.291, 預測: 2.291
# 第20220筆資料, 真實標籤: 3.582, 預測: 3.582
# 第20221筆資料, 真實標籤: 3.49, 預測: 3.49
# 第20222筆資料, 真實標籤: 3.852, 預測: 3.852
# 第20223筆資料, 真實標籤: 3.239, 預測: 3.239
# 第20224筆資料, 真實標籤: 1.868, 預測: 1.868
# 第20225筆資料, 真實標籤: 1.708, 預測: 1.708
# 第20226筆資料, 真實標籤: 1.653, 預測: 1.653
# 第20227筆資料, 真實標籤: 1.605, 預測: 1.605
# 第20228筆資料, 真實標籤: 1.927, 預測: 1.927
# 第20229筆資料, 真實標籤: 1.925, 預測: 1.925
# 第20230筆資料, 真實標籤: 1.875, 預測: 1.875
# 第20231筆資料, 真實標籤: 3.955, 預測: 3.955
# 第20232筆資料, 真實標籤: 3.591, 預測: 3.591
# 第20233筆資料, 真實標籤: 2.75, 預測: 2.75
# 第20234筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20235筆資料, 真實標籤: 2.038, 預測: 2.038
# 第20236筆資料, 真實標籤: 2.063, 預測: 2.063
# 第20237筆資料, 真實標籤: 1.984, 預測: 1.984
# 第20238筆資料, 真實標籤: 2.066, 預測: 2.066
# 第20239筆資料, 真實標籤: 3.846, 預測: 3.846
# 第20240筆資料, 真實標籤: 1.667, 預測: 1.667
# 第20241筆資料, 真實標籤: 2.212, 預測: 2.212
# 第20242筆資料, 真實標籤: 2.205, 預測: 2.205
# 第20243筆資料, 真實標籤: 2.445, 預測: 2.445
# 第20244筆資料, 真實標籤: 2.149, 預測: 2.149
# 第20245筆資料, 真實標籤: 2.19, 預測: 2.19
# 第20246筆資料, 真實標籤: 2.09, 預測: 2.09
# 第20247筆資料, 真實標籤: 2.127, 預測: 2.127
# 第20248筆資料, 真實標籤: 2.143, 預測: 2.143
# 第20249筆資料, 真實標籤: 2.75, 預測: 2.75
# 第20250筆資料, 真實標籤: 3.018, 預測: 3.018
# 第20251筆資料, 真實標籤: 1.125, 預測: 1.125
# 第20252筆資料, 真實標籤: 2.188, 預測: 2.188
# 第20253筆資料, 真實標籤: 2.199, 預測: 2.199
# 第20254筆資料, 真實標籤: 2.343, 預測: 2.343
# 第20255筆資料, 真實標籤: 1.987, 預測: 1.987
# 第20256筆資料, 真實標籤: 1.971, 預測: 1.971
# 第20257筆資料, 真實標籤: 1.435, 預測: 1.435
# 第20258筆資料, 真實標籤: 1.603, 預測: 1.603
# 第20259筆資料, 真實標籤: 1.493, 預測: 2.568362413793103
# 第20260筆資料, 真實標籤: 1.069, 預測: 1.069
# 第20261筆資料, 真實標籤: 2.347, 預測: 2.347
# 第20262筆資料, 真實標籤: 2.576, 預測: 2.576
# 第20263筆資料, 真實標籤: 2.354, 預測: 2.354
# 第20264筆資料, 真實標籤: 2.245, 預測: 2.245
# 第20265筆資料, 真實標籤: 2.539, 預測: 2.539
# 第20266筆資料, 真實標籤: 2.082, 預測: 2.082
# 第20267筆資料, 真實標籤: 2.139, 預測: 2.139
# 第20268筆資料, 真實標籤: 2.205, 預測: 2.205
# 第20269筆資料, 真實標籤: 1.674, 預測: 1.7785999999999997
# 第20270筆資料, 真實標籤: 1.708, 預測: 1.708
# 第20271筆資料, 真實標籤: 0.875, 預測: 0.875
# 第20272筆資料, 真實標籤: 4.233, 預測: 4.233
# 第20273筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20274筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20275筆資料, 真實標籤: 3.804, 預測: 3.804
# 第20276筆資料, 真實標籤: 2.295, 預測: 2.295
# 第20277筆資料, 真實標籤: 2.429, 預測: 2.429
# 第20278筆資料, 真實標籤: 2.312, 預測: 2.9255
# 第20279筆資料, 真實標籤: 2.185, 預測: 2.185
# 第20280筆資料, 真實標籤: 1.854, 預測: 1.854
# 第20281筆資料, 真實標籤: 1.805, 預測: 1.805
# 第20282筆資料, 真實標籤: 1.811, 預測: 1.811
# 第20283筆資料, 真實標籤: 1.791, 預測: 1.791
# 第20284筆資料, 真實標籤: 1.758, 預測: 1.758
# 第20285筆資料, 真實標籤: 1.724, 預測: 1.724
# 第20286筆資料, 真實標籤: 1.856, 預測: 1.856
# 第20287筆資料, 真實標籤: 1.821, 預測: 1.821
# 第20288筆資料, 真實標籤: 1.649, 預測: 1.649
# 第20289筆資料, 真實標籤: 1.88, 預測: 1.88
# 第20290筆資料, 真實標籤: 1.951, 預測: 1.951
# 第20291筆資料, 真實標籤: 1.868, 預測: 1.868
# 第20292筆資料, 真實標籤: 1.873, 預測: 1.873
# 第20293筆資料, 真實標籤: 1.876, 預測: 1.876
# 第20294筆資料, 真實標籤: 1.862, 預測: 1.862
# 第20295筆資料, 真實標籤: 1.911, 預測: 1.911
# 第20296筆資料, 真實標籤: 1.89, 預測: 1.89
# 第20297筆資料, 真實標籤: 1.834, 預測: 1.834
# 第20298筆資料, 真實標籤: 4.5, 預測: 4.5
# 第20299筆資料, 真實標籤: 1.656, 預測: 1.656
# 第20300筆資料, 真實標籤: 2.152, 預測: 2.152
# 第20301筆資料, 真實標籤: 1.854, 預測: 1.854
# 第20302筆資料, 真實標籤: 1.608, 預測: 1.608
# 第20303筆資料, 真實標籤: 3.058, 預測: 3.058
# 第20304筆資料, 真實標籤: 1.674, 預測: 1.674
# 第20305筆資料, 真實標籤: 1.86, 預測: 1.86
# 第20306筆資料, 真實標籤: 1.92, 預測: 1.92
# 第20307筆資料, 真實標籤: 2.054, 預測: 2.054
# 第20308筆資料, 真實標籤: 1.461, 預測: 1.461
# 第20309筆資料, 真實標籤: 2.068, 預測: 2.068
# 第20310筆資料, 真實標籤: 1.944, 預測: 1.944
# 第20311筆資料, 真實標籤: 0.675, 預測: 0.675
# 第20312筆資料, 真實標籤: 2.438, 預測: 2.438
# 第20313筆資料, 真實標籤: 1.75, 預測: 1.75
# 第20314筆資料, 真實標籤: 2.077, 預測: 2.077
# 第20315筆資料, 真實標籤: 1.966, 預測: 1.966
# 第20316筆資料, 真實標籤: 2.8, 預測: 2.8
# 第20317筆資料, 真實標籤: 2.239, 預測: 2.239
# 第20318筆資料, 真實標籤: 1.943, 預測: 1.943
# 第20319筆資料, 真實標籤: 1.693, 預測: 2.2416666666666667
# 第20320筆資料, 真實標籤: 1.893, 預測: 1.893
# 第20321筆資料, 真實標籤: 1.868, 預測: 1.703
# 第20322筆資料, 真實標籤: 2.132, 預測: 2.132
# 第20323筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20324筆資料, 真實標籤: 1.82, 預測: 1.82
# 第20325筆資料, 真實標籤: 1.941, 預測: 1.941
# 第20326筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20327筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20328筆資料, 真實標籤: 3.912, 預測: 3.912
# 第20329筆資料, 真實標籤: 4.521, 預測: 4.521
# 第20330筆資料, 真實標籤: 2.287, 預測: 2.287
# 第20331筆資料, 真實標籤: 3.406, 預測: 3.406
# 第20332筆資料, 真實標籤: 3.119, 預測: 3.119
# 第20333筆資料, 真實標籤: 2.796, 預測: 2.796
# 第20334筆資料, 真實標籤: 2.842, 預測: 2.842
# 第20335筆資料, 真實標籤: 2.322, 預測: 2.613
# 第20336筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20337筆資料, 真實標籤: 2.17, 預測: 2.17
# 第20338筆資料, 真實標籤: 2.381, 預測: 2.381
# 第20339筆資料, 真實標籤: 2.713, 預測: 2.713
# 第20340筆資料, 真實標籤: 2.326, 預測: 2.326
# 第20341筆資料, 真實標籤: 2.508, 預測: 2.508
# 第20342筆資料, 真實標籤: 2.142, 預測: 2.142
# 第20343筆資料, 真實標籤: 2.466, 預測: 2.466
# 第20344筆資料, 真實標籤: 2.575, 預測: 2.575
# 第20345筆資料, 真實標籤: 2.217, 預測: 2.217
# 第20346筆資料, 真實標籤: 2.228, 預測: 2.228
# 第20347筆資料, 真實標籤: 1.771, 預測: 1.771
# 第20348筆資料, 真實標籤: 2.279, 預測: 2.279
# 第20349筆資料, 真實標籤: 2.75, 預測: 2.75
# 第20350筆資料, 真實標籤: 1.25, 預測: 1.25
# 第20351筆資料, 真實標籤: 3.19, 預測: 2.613
# 第20352筆資料, 真實標籤: 2.182, 預測: 2.182
# 第20353筆資料, 真實標籤: 0.525, 預測: 0.525
# 第20354筆資料, 真實標籤: 2.75, 預測: 2.75
# 第20355筆資料, 真實標籤: 2.931, 預測: 2.931
# 第20356筆資料, 真實標籤: 1.625, 預測: 1.625
# 第20357筆資料, 真實標籤: 2.582, 預測: 2.582
# 第20358筆資料, 真實標籤: 2.413, 預測: 2.413
# 第20359筆資料, 真實標籤: 2.549, 預測: 2.549
# 第20360筆資料, 真實標籤: 3.449, 預測: 3.449
# 第20361筆資料, 真實標籤: 2.994, 預測: 2.994
# 第20362筆資料, 真實標籤: 2.356, 預測: 2.356
# 第20363筆資料, 真實標籤: 2.476, 預測: 2.476
# 第20364筆資料, 真實標籤: 2.915, 預測: 2.915
# 第20365筆資料, 真實標籤: 2.879, 預測: 2.879
# 第20366筆資料, 真實標籤: 2.593, 預測: 2.593
# 第20367筆資料, 真實標籤: 2.948, 預測: 2.948
# 第20368筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20369筆資料, 真實標籤: 1.76, 預測: 1.76
# 第20370筆資料, 真實標籤: 3.026, 預測: 3.026
# 第20371筆資料, 真實標籤: 3.338, 預測: 3.338
# 第20372筆資料, 真實標籤: 3.138, 預測: 3.138
# 第20373筆資料, 真實標籤: 4.107, 預測: 4.107
# 第20374筆資料, 真實標籤: 3.188, 預測: 3.188
# 第20375筆資料, 真實標籤: 3.994, 預測: 3.994
# 第20376筆資料, 真實標籤: 3.585, 預測: 3.585
# 第20377筆資料, 真實標籤: 4.108, 預測: 4.108
# 第20378筆資料, 真實標籤: 3.663, 預測: 3.663
# 第20379筆資料, 真實標籤: 3.375, 預測: 3.375
# 第20380筆資料, 真實標籤: 2.332, 預測: 2.332
# 第20381筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20382筆資料, 真實標籤: 3.218, 預測: 3.218
# 第20383筆資料, 真實標籤: 4.234, 預測: 4.234
# 第20384筆資料, 真實標籤: 2.288, 預測: 2.288
# 第20385筆資料, 真實標籤: 2.394, 預測: 2.394
# 第20386筆資料, 真實標籤: 2.421, 預測: 2.421
# 第20387筆資料, 真實標籤: 2.813, 預測: 2.2054
# 第20388筆資料, 真實標籤: 1.304, 預測: 1.7785999999999997
# 第20389筆資料, 真實標籤: 4.521, 預測: 2.2054
# 第20390筆資料, 真實標籤: 5.00001, 預測: 3.9502019999999995
# 第20391筆資料, 真實標籤: 3.12, 預測: 3.12
# 第20392筆資料, 真實標籤: 2.646, 預測: 2.646
# 第20393筆資料, 真實標籤: 2.871, 預測: 2.871
# 第20394筆資料, 真實標籤: 3.027, 預測: 3.027
# 第20395筆資料, 真實標籤: 3.054, 預測: 3.054
# 第20396筆資料, 真實標籤: 3.429, 預測: 3.429
# 第20397筆資料, 真實標籤: 2.909, 預測: 2.909
# 第20398筆資料, 真實標籤: 2.322, 預測: 2.322
# 第20399筆資料, 真實標籤: 2.517, 預測: 2.517
# 第20400筆資料, 真實標籤: 2.514, 預測: 2.514
# 第20401筆資料, 真實標籤: 2.414, 預測: 2.414
# 第20402筆資料, 真實標籤: 2.067, 預測: 2.067
# 第20403筆資料, 真實標籤: 2.118, 預測: 2.118
# 第20404筆資料, 真實標籤: 2.748, 預測: 2.748
# 第20405筆資料, 真實標籤: 2.58, 預測: 2.58
# 第20406筆資料, 真實標籤: 3.0, 預測: 3.0
# 第20407筆資料, 真實標籤: 2.868, 預測: 2.568362413793103
# 第20408筆資料, 真實標籤: 3.16, 預測: 3.16
# 第20409筆資料, 真實標籤: 3.099, 預測: 3.9502019999999995
# 第20410筆資料, 真實標籤: 2.646, 預測: 2.568362413793103
# 第20411筆資料, 真實標籤: 2.435, 預測: 2.435
# 第20412筆資料, 真實標籤: 2.407, 預測: 2.407
# 第20413筆資料, 真實標籤: 2.287, 預測: 2.287
# 第20414筆資料, 真實標籤: 2.128, 預測: 2.128
# 第20415筆資料, 真實標籤: 1.738, 預測: 1.738
# 第20416筆資料, 真實標籤: 1.875, 預測: 1.875
# 第20417筆資料, 真實標籤: 3.237, 預測: 2.568362413793103
# 第20418筆資料, 真實標籤: 4.229, 預測: 3.9502019999999995
# 第20419筆資料, 真實標籤: 3.929, 預測: 3.9502019999999995
# 第20420筆資料, 真實標籤: 3.494, 預測: 3.9502019999999995
# 第20421筆資料, 真實標籤: 3.483, 預測: 3.483
# 第20422筆資料, 真實標籤: 3.539, 預測: 2.9255
# 第20423筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20424筆資料, 真實標籤: 4.286, 預測: 4.286
# 第20425筆資料, 真實標籤: 3.576, 預測: 3.576
# 第20426筆資料, 真實標籤: 3.259, 預測: 3.259
# 第20427筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20428筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20429筆資料, 真實標籤: 4.258, 預測: 4.258
# 第20430筆資料, 真實標籤: 3.619, 預測: 3.619
# 第20431筆資料, 真實標籤: 2.247, 預測: 2.247
# 第20432筆資料, 真實標籤: 2.827, 預測: 2.827
# 第20433筆資料, 真實標籤: 2.147, 預測: 2.147
# 第20434筆資料, 真實標籤: 2.224, 預測: 2.224
# 第20435筆資料, 真實標籤: 2.043, 預測: 2.043
# 第20436筆資料, 真實標籤: 2.53, 預測: 2.53
# 第20437筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20438筆資料, 真實標籤: 3.208, 預測: 3.208
# 第20439筆資料, 真實標籤: 4.019, 預測: 4.019
# 第20440筆資料, 真實標籤: 2.641, 預測: 2.641
# 第20441筆資料, 真實標籤: 3.081, 預測: 3.081
# 第20442筆資料, 真實標籤: 2.545, 預測: 2.545
# 第20443筆資料, 真實標籤: 4.047, 預測: 4.047
# 第20444筆資料, 真實標籤: 5.00001, 預測: 5.00001
# 第20445筆資料, 真實標籤: 2.086, 預測: 2.086
# 第20446筆資料, 真實標籤: 2.426, 預測: 2.426
# 第20447筆資料, 真實標籤: 1.941, 預測: 1.941
# 第20448筆資料, 真實標籤: 3.75, 預測: 3.75
# 第20449筆資料, 真實標籤: 1.957, 預測: 1.957
# 第20450筆資料, 真實標籤: 1.821, 預測: 1.821
# 第20451筆資料, 真實標籤: 2.802, 預測: 2.802
# 第20452筆資料, 真實標籤: 3.213, 預測: 3.213
# 第20453筆資料, 真實標籤: 1.968, 預測: 1.968
# 第20454筆資料, 真實標籤: 1.709, 預測: 1.709
# 第20455筆資料, 真實標籤: 1.985, 預測: 1.985
# 第20456筆資料, 真實標籤: 1.964, 預測: 1.964
# 第20457筆資料, 真實標籤: 2.099, 預測: 2.099
# 第20458筆資料, 真實標籤: 2.082, 預測: 2.082
# 第20459筆資料, 真實標籤: 1.852, 預測: 1.852
# 第20460筆資料, 真實標籤: 1.877, 預測: 1.877
# 第20461筆資料, 真實標籤: 2.581, 預測: 2.581
# 第20462筆資料, 真實標籤: 2.399, 預測: 2.399
# 第20463筆資料, 真實標籤: 2.663, 預測: 2.663
# 第20464筆資料, 真實標籤: 2.644, 預測: 2.644
# 第20465筆資料, 真實標籤: 1.866, 預測: 1.866
# 第20466筆資料, 真實標籤: 1.88, 預測: 1.88
# 第20467筆資料, 真實標籤: 2.333, 預測: 2.333
# 第20468筆資料, 真實標籤: 2.25, 預測: 2.25
# 第20469筆資料, 真實標籤: 1.794, 預測: 1.794
# 第20470筆資料, 真實標籤: 2.053, 預測: 2.053
# 第20471筆資料, 真實標籤: 2.15, 預測: 2.15
# 第20472筆資料, 真實標籤: 1.969, 預測: 1.969
# 第20473筆資料, 真實標籤: 1.904, 預測: 1.904
# 第20474筆資料, 真實標籤: 2.221, 預測: 2.221
# 第20475筆資料, 真實標籤: 1.981, 預測: 1.981
# 第20476筆資料, 真實標籤: 1.934, 預測: 1.934
# 第20477筆資料, 真實標籤: 2.041, 預測: 2.041
# 第20478筆資料, 真實標籤: 2.21, 預測: 2.21
# 第20479筆資料, 真實標籤: 2.258, 預測: 2.258
# 第20480筆資料, 真實標籤: 1.866, 預測: 1.866
# 第20481筆資料, 真實標籤: 1.961, 預測: 1.961
# 第20482筆資料, 真實標籤: 2.5, 預測: 2.5
# 第20483筆資料, 真實標籤: 2.239, 預測: 2.239
# 第20484筆資料, 真實標籤: 2.177, 預測: 2.177
# 第20485筆資料, 真實標籤: 2.186, 預測: 2.186
# 第20486筆資料, 真實標籤: 2.353, 預測: 2.353
# 第20487筆資料, 真實標籤: 2.38, 預測: 2.38
# 第20488筆資料, 真實標籤: 3.93, 預測: 3.93
# 第20489筆資料, 真實標籤: 2.23, 預測: 2.23
# 第20490筆資料, 真實標籤: 2.252, 預測: 2.252
# 第20491筆資料, 真實標籤: 2.091, 預測: 2.091
# 第20492筆資料, 真實標籤: 1.918, 預測: 1.918
# 第20493筆資料, 真實標籤: 2.046, 預測: 2.046
# 第20494筆資料, 真實標籤: 2.292, 預測: 2.292
# 第20495筆資料, 真實標籤: 3.02, 預測: 3.02
# 第20496筆資料, 真實標籤: 2.212, 預測: 2.212
# 第20497筆資料, 真實標籤: 2.383, 預測: 2.383
# 第20498筆資料, 真實標籤: 2.441, 預測: 2.441
# 第20499筆資料, 真實標籤: 2.298, 預測: 2.298
# 第20500筆資料, 真實標籤: 2.367, 預測: 2.367
# 第20501筆資料, 真實標籤: 2.27, 預測: 2.27
# 第20502筆資料, 真實標籤: 3.35, 預測: 3.35
# 第20503筆資料, 真實標籤: 3.25, 預測: 3.25
# 第20504筆資料, 真實標籤: 3.3, 預測: 3.3
# 第20505筆資料, 真實標籤: 3.439, 預測: 3.439
# 第20506筆資料, 真實標籤: 2.48, 預測: 2.48
# 第20507筆資料, 真實標籤: 2.765, 預測: 2.765
# 第20508筆資料, 真實標籤: 0.691, 預測: 0.691
# 第20509筆資料, 真實標籤: 0.76, 預測: 0.76
# 第20510筆資料, 真實標籤: 0.802, 預測: 0.802
# 第20511筆資料, 真實標籤: 0.748, 預測: 0.748
# 第20512筆資料, 真實標籤: 0.678, 預測: 0.678
# 第20513筆資料, 真實標籤: 0.696, 預測: 0.696
# 第20514筆資料, 真實標籤: 2.25, 預測: 2.25
# 第20515筆資料, 真實標籤: 0.325, 預測: 0.325
# 第20516筆資料, 真實標籤: 0.866, 預測: 0.866
# 第20517筆資料, 真實標籤: 0.862, 預測: 0.862
# 第20518筆資料, 真實標籤: 0.743, 預測: 0.743
# 第20519筆資料, 真實標籤: 0.823, 預測: 0.823
# 第20520筆資料, 真實標籤: 0.764, 預測: 0.764
# 第20521筆資料, 真實標籤: 0.792, 預測: 0.792
# 第20522筆資料, 真實標籤: 1.185, 預測: 1.185
# 第20523筆資料, 真實標籤: 0.731, 預測: 0.731
# 第20524筆資料, 真實標籤: 1.469, 預測: 1.469
# 第20525筆資料, 真實標籤: 1.159, 預測: 1.159
# 第20526筆資料, 真實標籤: 1.417, 預測: 1.417
# 第20527筆資料, 真實標籤: 1.569, 預測: 1.569
# 第20528筆資料, 真實標籤: 3.1, 預測: 3.1
# 第20529筆資料, 真實標籤: 2.232, 預測: 2.232
# 第20530筆資料, 真實標籤: 2.043, 預測: 2.043
# 第20531筆資料, 真實標籤: 2.018, 預測: 2.018
# 第20532筆資料, 真實標籤: 2.86, 預測: 2.86
# 第20533筆資料, 真實標籤: 1.536, 預測: 1.536
# 第20534筆資料, 真實標籤: 3.265, 預測: 3.265
# 第20535筆資料, 真實標籤: 1.791, 預測: 1.791
# 第20536筆資料, 真實標籤: 1.485, 預測: 1.485
# 第20537筆資料, 真實標籤: 1.308, 預測: 1.308
# 第20538筆資料, 真實標籤: 1.375, 預測: 1.375
# 第20539筆資料, 真實標籤: 1.452, 預測: 1.452
# 第20540筆資料, 真實標籤: 1.641, 預測: 1.641
# 第20541筆資料, 真實標籤: 1.943, 預測: 1.943
# 第20542筆資料, 真實標籤: 2.265, 預測: 2.265
# 第20543筆資料, 真實標籤: 2.362, 預測: 2.362
# 第20544筆資料, 真實標籤: 1.826, 預測: 1.826
# 第20545筆資料, 真實標籤: 2.194, 預測: 2.194
# 第20546筆資料, 真實標籤: 2.277, 預測: 2.277
# 第20547筆資料, 真實標籤: 1.231, 預測: 1.231
# 第20548筆資料, 真實標籤: 1.079, 預測: 1.079
# 第20549筆資料, 真實標籤: 0.694, 預測: 0.694
# 第20550筆資料, 真實標籤: 1.222, 預測: 1.222
# 第20551筆資料, 真實標籤: 1.031, 預測: 1.031
# 第20552筆資料, 真實標籤: 0.958, 預測: 0.958
# 第20553筆資料, 真實標籤: 1.206, 預測: 1.206
# 第20554筆資料, 真實標籤: 0.953, 預測: 0.953
# 第20555筆資料, 真實標籤: 0.978, 預測: 0.978
# 第20556筆資料, 真實標籤: 1.72, 預測: 1.72
# 第20557筆資料, 真實標籤: 1.525, 預測: 1.525
# 第20558筆資料, 真實標籤: 1.194, 預測: 1.194
# 第20559筆資料, 真實標籤: 1.544, 預測: 1.544
# 第20560筆資料, 真實標籤: 1.672, 預測: 1.672
# 第20561筆資料, 真實標籤: 1.469, 預測: 1.469
# 第20562筆資料, 真實標籤: 1.089, 預測: 1.089
# 第20563筆資料, 真實標籤: 1.072, 預測: 1.072
# 第20564筆資料, 真實標籤: 1.325, 預測: 1.325
# 第20565筆資料, 真實標籤: 1.514, 預測: 1.514
# 第20566筆資料, 真實標籤: 2.25, 預測: 2.25
# 第20567筆資料, 真實標籤: 2.007, 預測: 2.007
# 第20568筆資料, 真實標籤: 1.65, 預測: 1.65
# 第20569筆資料, 真實標籤: 1.399, 預測: 1.399
# 第20570筆資料, 真實標籤: 1.334, 預測: 1.334
# 第20571筆資料, 真實標籤: 1.396, 預測: 1.396
# 第20572筆資料, 真實標籤: 1.273, 預測: 1.273
# 第20573筆資料, 真實標籤: 1.267, 預測: 1.267
# 第20574筆資料, 真實標籤: 2.25, 預測: 2.25
# 第20575筆資料, 真實標籤: 1.938, 預測: 1.938
# 第20576筆資料, 真實標籤: 1.875, 預測: 1.875
# 第20577筆資料, 真實標籤: 0.984, 預測: 0.984
# 第20578筆資料, 真實標籤: 0.917, 預測: 0.917
# 第20579筆資料, 真實標籤: 2.75, 預測: 2.75
# 第20580筆資料, 真實標籤: 0.784, 預測: 1.0772
# 第20581筆資料, 真實標籤: 0.879, 預測: 0.879
# 第20582筆資料, 真實標籤: 1.234, 預測: 1.234
# 第20583筆資料, 真實標籤: 0.927, 預測: 0.927
# 第20584筆資料, 真實標籤: 1.375, 預測: 1.375
# 第20585筆資料, 真實標籤: 0.698, 預測: 0.698
# 第20586筆資料, 真實標籤: 0.836, 預測: 0.836
# 第20587筆資料, 真實標籤: 0.963, 預測: 0.963
# 第20588筆資料, 真實標籤: 0.703, 預測: 0.714
# 第20589筆資料, 真實標籤: 0.613, 預測: 0.613
# 第20590筆資料, 真實標籤: 0.589, 預測: 0.589
# 第20591筆資料, 真實標籤: 0.713, 預測: 0.713
# 第20592筆資料, 真實標籤: 0.555, 預測: 0.555
# 第20593筆資料, 真實標籤: 0.55, 預測: 0.55
# 第20594筆資料, 真實標籤: 0.798, 預測: 0.798
# 第20595筆資料, 真實標籤: 0.847, 預測: 0.847
# 第20596筆資料, 真實標籤: 0.888, 預測: 0.888
# 第20597筆資料, 真實標籤: 0.685, 預測: 0.685
# 第20598筆資料, 真實標籤: 0.687, 預測: 0.687
# 第20599筆資料, 真實標籤: 0.555, 預測: 0.555
# 第20600筆資料, 真實標籤: 0.63, 預測: 0.63
# 第20601筆資料, 真實標籤: 0.717, 預測: 0.717
# 第20602筆資料, 真實標籤: 0.579, 預測: 0.579
# 第20603筆資料, 真實標籤: 0.697, 預測: 0.697
# 第20604筆資料, 真實標籤: 0.596, 預測: 0.596
# 第20605筆資料, 真實標籤: 0.65, 預測: 0.65
# 第20606筆資料, 真實標籤: 0.612, 預測: 0.612
# 第20607筆資料, 真實標籤: 0.566, 預測: 0.566
# 第20608筆資料, 真實標籤: 0.623, 預測: 0.623
# 第20609筆資料, 真實標籤: 0.488, 預測: 0.488
# 第20610筆資料, 真實標籤: 0.575, 預測: 0.575
# 第20611筆資料, 真實標籤: 0.455, 預測: 0.455
# 第20612筆資料, 真實標籤: 0.47, 預測: 0.47
# 第20613筆資料, 真實標籤: 0.483, 預測: 0.483
# 第20614筆資料, 真實標籤: 0.534, 預測: 0.534
# 第20615筆資料, 真實標籤: 0.58, 預測: 0.58
# 第20616筆資料, 真實標籤: 0.575, 預測: 0.575
# 第20617筆資料, 真實標籤: 0.551, 預測: 0.551
# 第20618筆資料, 真實標籤: 0.708, 預測: 0.708
# 第20619筆資料, 真實標籤: 0.634, 預測: 0.634
# 第20620筆資料, 真實標籤: 0.991, 預測: 0.991
# 第20621筆資料, 真實標籤: 1.0, 預測: 1.0
# 第20622筆資料, 真實標籤: 0.775, 預測: 0.775
# 第20623筆資料, 真實標籤: 0.67, 預測: 0.67
# 第20624筆資料, 真實標籤: 0.655, 預測: 0.655
# 第20625筆資料, 真實標籤: 0.872, 預測: 0.872
# 第20626筆資料, 真實標籤: 0.72, 預測: 0.72
# 第20627筆資料, 真實標籤: 0.938, 預測: 0.938
# 第20628筆資料, 真實標籤: 1.625, 預測: 1.625
# 第20629筆資料, 真實標籤: 0.924, 預測: 0.924
# 第20630筆資料, 真實標籤: 1.083, 預測: 1.083
# 第20631筆資料, 真實標籤: 1.12, 預測: 1.12
# 第20632筆資料, 真實標籤: 1.072, 預測: 1.072
# 第20633筆資料, 真實標籤: 1.156, 預測: 1.156
# 第20634筆資料, 真實標籤: 0.983, 預測: 0.983
# 第20635筆資料, 真實標籤: 1.168, 預測: 1.168
# 第20636筆資料, 真實標籤: 0.781, 預測: 0.781
# 第20637筆資料, 真實標籤: 0.771, 預測: 0.771
# 第20638筆資料, 真實標籤: 0.923, 預測: 0.923
# 第20639筆資料, 真實標籤: 0.847, 預測: 0.847
# 第20640筆資料, 真實標籤: 0.894, 預測: 0.894

# %%
## 查看MSE、MAE
mse = round(mean_squared_error(dt.pred.iloc[:, -1], dt.pred.iloc[:, -2]), 4)
mae = round(mean_absolute_error(dt.pred.iloc[:, -1], dt.pred.iloc[:, -2]), 4)
mape = round(mean_absolute_percentage_error(dt.pred.iloc[:, -1], dt.pred.iloc[:, -2]), 4)

print(f"MAPE: {mape}, MAE: {mae}, MSE: {mse}")
# Out:
# MAPE: 0.0158, MAE: 0.028, MSE: 0.0241

# %%
# %%time
## 使用sklearn DT

dt_sklearn = DecisionTreeRegressor().fit(X, y)
# Out:
# Wall time: 394 ms

# %%
## 查看MSE、MAE
y_pred = dt_sklearn.predict(X)

mse = round(mean_squared_error(dt.pred.iloc[:, -1], y_pred), 4)
mae = round(mean_absolute_error(dt.pred.iloc[:, -1], y_pred), 4)
mape = round(mean_absolute_percentage_error(dt.pred.iloc[:, -1], y_pred), 4)

print(f"MAPE: {mape}, MAE: {mae}, MSE: {mse}")
# Out:
# MAPE: 0.0, MAE: 0.0, MSE: 0.0
